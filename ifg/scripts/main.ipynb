# %% [markdown]
# # Main IFG Script
# Creates functional group data excel file given a target set of smiles codes.
#
# Before running this script, ensure that IFG had been installed to your computer.  <br>
# To see more information about this script, please view the doc page for this script at the [IFG docs]()

# %% [markdown]
# ## Script Modules and Packages

# %% [markdown]
# Imported modules and usages:
#
# - <b>csv</b> loads SMILES csv file data into python variables
# - <b>os</b> gets file paths for python to locate files on computer file system
# - <b>logging</b> logs structures which fail the functional group processing algorithm
# - <b>traceback</b> collects the exact python error for failed structures
# - <b>pandas</b> tabulates functional group python data and exports it to excel
# - <b>tqdm</b> shows visual progress bar of processing through each SMILES structure
# - <b>chem.molecule</b> imports the SMILES-based computation logic to compute the functional groups present in a SMILES code created from the IFG python package

# %%
import csv
import logging
import os
import traceback

import pandas
from tqdm import tqdm

from chem.molecule import Molecule

# %% [markdown]
# ## Script I/O Files

# %% [markdown]
# File path to csv file of SMILES codes to process in this script

# %%
STRUCTURES_PATH = os.getcwd() + "/smiles/smiles.csv"
print(STRUCTURES_PATH)
# Out:
# c:\Users\wtrid\Documents\Software Development\IFG\ifg\scripts/smiles/smiles.csv

# %% [markdown]
# File path to excel file that will be generated by this script

# %%
MAIN_OUTPUT_PATH = os.getcwd() + '/output/functional_groups.xlsx'
print(MAIN_OUTPUT_PATH)
# Out:
# c:\Users\wtrid\Documents\Software Development\IFG\ifg\scripts/output/functional_groups.xlsx

# %% [markdown]
# ## Script Data Set-Up

# %% [markdown]
# SMILES codes data load
#
# The SMILES code loading below uses the file path to the SMILES code csv file <b>STRUCTURES_PATH</b> and the python module <b>csv</b> to read in its data row by row and save it into a variable called <b>STRUCTURES</b>. The csv file variable is used because it is initally a file object from the <b>csv</b> module, then the data is pulled out into a python list called <b>STRUCTURES</b>.
#
# Please ensure that your csv file format matches with the default. If you receive an error in loading, please consider adjusting your csv file format to the default, or load in the data according to your needs. Also, ensure that the SMILES code formats are usable by the IFG pacakge.

# %%
STRUCTURES_CSV_FILE = csv.reader(open(STRUCTURES_PATH, "r+", encoding="UTF-8"))
STRUCTURES = [(smiles,refcode) for (smiles,refcode) in STRUCTURES_CSV_FILE][1:]
STRUCTURES
# Out:
# [('CC(=O)NCCNC(C)=O', 'ABAWEG01'),
#  ('c1ccc2c(c1)cccc2C#Cc1ccccc1C#Cc1cccc2ccccc12', 'ABEJIC'),
#  ('O=C1NC2C(N(CN2N(=O)=O)N(=O)=O)N1N(=O)=O', 'ABEJOH'),
#  ('COC', 'ABEWAG'),
#  ('CC(O)=O', 'ACETAC07'),
#  ('CC(=O)Nc1ccc(C)cc1', 'ACTOLD07'),
#  ('OCC1OC(O)C(O)C(O)C1O', 'ADGALA03'),
#  ('COC(=O)c1nccnc1N', 'ADUWUS01'),
#  ('[N+]C1CCC2CCC(N2C1=O)C(=O)[O-]', 'AFAFAP'),
#  ('CC1(C)OC(CC(O)=O)C(=O)O1', 'AFEREJ'),
#  ('CC1(CC2CCCCN2O1)C#N', 'AHETOX'),
#  ('CC(C)C(=O)NCc1ccccc1', 'AHEYOC'),
#  ('N#Cc1cccc(Oc2cccnc2)c1C#N', 'AHITUH'),
#  ('CC(C)(C)c1ccc(O)c(CN2CCN(CC2)Cc2cc(ccc2O)C(C)(C)C)c1', 'AHOPOD'),
#  ('[N+]C(C)C(=O)[O-]', 'ALUCAL05'),
#  ('O=C(Nc1cccc2ccccc12)Nc1cccc2ccccc12', 'AMAFEZ01'),
#  ('[N+]CCCCCC(=O)[O-]', 'AMCAPR11'),
#  ('CC1(C)O[N+](=C2CCCCC2=C1)[O-]', 'ANAXOD'),
#  ('COc1ccc(cc1)C(O)=O', 'ANISIC04'),
#  ('CC1(COc2cc(ccc12)C(=O)N1CCCCC1)Cc1ccccc1', 'ANIVID'),
#  ('CC1(CCCCC1)OC(=O)c1c2ccccc2cc2ccccc12', 'ANOBAH'),
#  ('CC(C)(C)OC(=O)C12C3c4ccccc4C(C(c4ccccc14)c1ccccc21)(C(=O)OC(C)(C)C)c1ccccc31',
#   'ANODAJ'),
#  ('COC(=O)C1CNc2ccccc2N2C=CN=C2C1O', 'APENIT'),
#  ('COC1OC(CO)C(O)C(O)C1NC=O', 'APOLUN'),
#  ('COC1(c2ccccc2)c2ccccc2C(OC)(c2ccccc2)c2ccccc12', 'APOXOT'),
#  ('O=C1NCCCN1', 'APYFEB01'),
#  ('COc1ccc(cc1)C1=NC(C)(OC21C(=O)N(C)c1ccccc21)C(=O)OC', 'ASOLUQ'),
#  ('C1CC21OC12CN(C1)C(c1ccccc1)c1ccccc1', 'ASUNAE'),
#  ('CC=CC1=CC(O)C(O)C1=O', 'ATUHEC'),
#  ('CC(=Nc1cc(ccc1C(C)(C)C)C(C)(C)C)C(C)=Nc1cc(ccc1C(C)(C)C)C(C)(C)C',
#   'ATUNAF'),
#  ('Cc1cc(C)cc(c1)N=C1C(=O)c2cccc3cccc1c23', 'ATUNOT'),
#  ('Cc1cccc(C)c1N=C1C(=O)c2cccc3cccc1c23', 'ATUPAH'),
#  ('CC(=O)Nc1ccc(N)cc1N(=O)=O', 'AVOJUR'),
#  ('CC(C)C1CCN(C1C(O)=O)C(=O)OCc1ccccc1', 'AWAVUQ'),
#  ('O=C1OC2C3CC(C=C3)C2C1Nc1ccc(cc1N(=O)=O)N(=O)=O', 'AXEGAM'),
#  ('CC(C#N)(c1ccccc1)C(=O)C(C)(C#N)c1ccccc1', 'AXOQOU'),
#  ('CC(=O)Oc1ccccc1', 'AXUDIH'),
#  ('C1CCC2=C(C1)N=C(Nc1ccccc1)N2c1ccccc1', 'AYATEA'),
#  ('CCOC(=O)C(=CC1=CC=CN1C)C#N', 'AYUGEH'),
#  ('CCOC(=O)C1=C(ON=C1C)C(C)=NN=C(C)C1=C(C(=O)OCC)C(=NO1)C', 'AYUGIL'),
#  ('OC(=O)C(CC1=CNc2ccccc12)[N+]=Cc1cccc(O)c1[O-]', 'AYUVOG'),
#  ('O=C1NC2=C(CCc3ccccc23)C(=C1C#N)c1ccccc1', 'AZAMOE'),
#  ('C1CC2CC1CC2C1CC2CCC1C2', 'AZIBEQ'),
#  ('CC1=C(N=CN1c1ccccc1)N(=O)=O', 'AZIQIJ'),
#  ('CC(C)(C)N([O])c1cc(cc(c1)c1ccccc1)N([O])C(C)(C)C', 'AZOMAD'),
#  ('CCCC1=Nc2cc(ccc2N1CCO)C(=O)OCC', 'AZUPUH'),
#  ('CCC(C)(C)c1cc(OC)c(cc1OC)C(C)(C)CC', 'AZUQOC'),
#  ('CC(=O)OCC1OC(C=CC1OC(C)=O)C1=CN(N=N1)c1ccccc1', 'AZUYEA'),
#  ('CN1N(c2ccccc2)C(=O)C(=C1C)C1=Nc2ccccc2N1', 'BABBOX'),
#  ('CC12CC(COC(=O)c3ccccc3)C1(O)CC(=O)C2', 'BABYOU'),
#  ('COC(=O)c1cc(c([n+]n1)C=C([O-])c1ccccc1)c1ccccc1', 'BAFDIX'),
#  ('O=C1N(C(=O)c2cccc3cccc1c23)c1ccccc1OCC#C', 'BAFPEF'),
#  ('O=C(C=C1CC(Nc2ncccc2N1)c1ccccc1)c1ccccc1', 'BAJYOB'),
#  ('CC(C)CC1=C(C(=O)NC1=O)c1ccc(OCC=C(C)C)cc1', 'BELWUL'),
#  ('OC1COc2ccc3ccccc3c2C1c1ccccc1', 'BEWPAV'),
#  ('CCC12CCC(C)(NC1=O)NC2=O', 'BEXMIB'),
#  ('O=C1NC2(CCC1C(=O)N2)c1ccccc1', 'BEXMUN'),
#  ('O=C1CCC2=C(C#N)c3cc4OCOc4cc3CCN12', 'BEXXUY'),
#  ('CC1OC(=O)C(C)OC1=O', 'BEYDEO01'),
#  ('OCC[N+](CCO)CC(=O)[O-]', 'BICINE01'),
#  ('CC1OC(=O)C(C)OC1=O', 'BICVIS02'),
#  ('CC(C)(C)OC(N)=O', 'BIFPEL01'),
#  ('COc1ccc(cc1)C1CC(=O)CC(=C(C)C)C(C1)=C(C)C', 'BIJYID'),
#  ('COC(=O)C=CC1C2CCC3C2C(C)(C)CCCC13C', 'BIVLEY'),
#  ('OCC1OC(OC2C(O)C(O)C(O)OC2CO)C(O)C(O)C1O', 'BLACTO02'),
#  ('Oc1cc2C(=O)c3ccccc3C(=O)c2cc1C=O', 'BOGWEA'),
#  ('COC1OC(C(O)C(N=[N+]=[N-])C(=O)OC)C2(O)C(O)COC12', 'BOKSIE'),
#  ('CNC(=O)C(O)C#N', 'BOLZIL'),
#  ('Cc1ccc(NC(=Nc2ccc(C)cc2)N2C=NC(=C2C)C)cc1', 'BORSUX'),
#  ('CC(C)NC(=NC(C)C)N1C(=NC(=C1C)C)C', 'BORTOS'),
#  ('COC1(CC(=O)c2ccccc2)OC(=O)C(=C1c1ccccc1)O', 'BOSJID'),
#  ('[N-]=[N+]=NC(N=[N+]=[N-])c1cc(C(N=[N+]=[N-])N=[N+]=[N-])c(cc1C(N=[N+]=[N-])N=[N+]=[N-])C(N=[N+]=[N-])N=[N+]=[N-]',
#   'BOTWAJ'),
#  ('CC1=C2C(c3ccccc3)C(=C(N)OC2=NN1)C#N', 'BOYZUL'),
#  ('CN1C=C(C(=N1)C(O)=O)N(=O)=O', 'BOZGED'),
#  ('CC(=O)OC1C2CC(O)C(O)CC(N2)C(OC(C)=O)C1OC(C)=O', 'BOZZAS'),
#  ('O=C(c1ccccc1)c1ccccc1', 'BPHENO12'),
#  ('COc1c(CC=C(C)C)c(C=O)cc2c1Nc1ccccc21', 'BUDWIH'),
#  ('N(C1C2N(C3C(Nc4ccccc4)N(C(C(N1c1ccccc1)N2c1ccccc1)N3c1ccccc1)c1ccccc1)c1ccccc1)c1ccccc1',
#   'BUFKAP'),
#  ('O=C1Nc2ccccc2O1', 'BZOXZO01'),
#  ('CC1(C)CCCC2(CCC(=O)OC2)C1CO', 'CAGMEE'),
#  ('O=C1C=CC2CC3=CCCC13O2', 'CAJDIC'),
#  ('CC1(CC(C)(CC(C)(C1)N=C=O)N=C=O)N=C=O', 'CAKREM'),
#  ('CCCCCCCOc1ccc(cc1)N=Nc1c(C)c(C)c(N=Nc2ccc(OCCCCCCC)cc2)c(C)c1C', 'CAMWIY'),
#  ('COc1ccc2OC3(CCc4cccc(OC)c4O3)Cc2c1', 'CASGAF'),
#  ('Oc1ccccc1O', 'CATCOL13'),
#  ('COC(=O)c1ccc(O)cc1', 'CEBGOF03'),
#  ('COc1ccc(C=CC(=O)c2ccc(OC)c(OC)c2)cc1', 'CICMEH'),
#  ('COC(=O)C=CC1CN(C(=O)N1C(C)(C)C)C(C)(C)C', 'CIFLUZ'),
#  ('OC(=O)C=Cc1ccccc1', 'CINMAC07'),
#  ('CC(C)(C)OC#CC#COC(C)(C)C', 'CITQAY'),
#  ('O=C1NC(Cc2ccccc2)C(=O)N2CCCC12', 'CITXAE11'),
#  ('CCCCCCC#Cc1c2cc3ccccc3cc2c(C#CCCCCCC)c2cc3ccccc3cc12', 'CIZCIY'),
#  ('Cc1cccc(C)c1OC(=O)N1C=CN=C1', 'CIZXUF'),
#  ('COC(=O)C12C(CCCC1=NNc1ccc(cc1N(=O)=O)N(=O)=O)C2=C=C', 'COHYEE'),
#  ('CC12CC3CCC1C3(O)OC2=O', 'COQZEO'),
#  ('CC(C)(C)OC(=O)C1CC(=NN1N=O)c1ccccc1', 'COSKOL'),
#  ('O=C1Oc2ccccc2C=C1', 'COUMAR11'),
#  ('O=N(=O)C1=NN(CC#N)N=N1', 'COXXOD'),
#  ('COc1ccc(O)c(C=NC(C)c2ccccc2)c1', 'CUCVEC'),
#  ('CC(=NO)C(=O)NN=Cc1ccccn1', 'CUDBEJ'),
#  ('c1ccc(cc1)C1=Cc2nc3ccccc3nc2C2=C(N=NN12)c1ccccc1', 'CUNDAR'),
#  ('OC(=O)c1ccc2C(=O)N(c3ccncc3)C(=O)c2c1', 'CUNWIS'),
#  ('CC1(C)C2(C)CCC1(OC2=O)C(=O)OC1C2OC3OC(C2O)C(O)C1O3', 'CUTWAQ'),
#  ('COC1OC2CC1C(C2)N(=O)=O', 'CUZXAX'),
#  ('OC(=O)C1CCCCC1C(O)=O', 'CYHCAC11'),
#  ('CN1C(=O)C2C(NC(C)=O)C=C(C)C(CC=C(C)C)C2C1=O', 'DACWIP'),
#  ('ON=C1CCCC21CCCC2=NO', 'DAFSUZ'),
#  ('C1CCN(CC1)CCN1CCCCC1', 'DAGLII'),
#  ('C1CCN(C1)CCN1CCCC1', 'DAGLOO'),
#  ('CCOC(=O)C1NC1C(=O)NCC(=O)NCC(=O)OCc1ccccc1', 'DAKCOI'),
#  ('COc1ccc(cc1)C=C1N(C)C(=O)c2ccccc12', 'DAKYOE'),
#  ('CC(=O)OC1C2OC(OC2O)C2(CCCCC12OC(C)=O)OC(C)=O', 'DAPSIX'),
#  ('OC1C(O)C2(O)CCCCC32COC1O3', 'DAPTEU'),
#  ('CC1(C)OCC2(OCC3OC(C)(C)OC3C2OCc2ccccc2)O1', 'DAXJES'),
#  ('CC(C)C(OC(=O)c1ccc(cc1)N(=O)=O)C1=C(C)CC2C1C2(C)C', 'DAXJIW'),
#  ('N(N=Nc1ccccc1)c1ccccc1', 'DAZABZ02'),
#  ('CCOC(=O)C1=COC=C1C(O)=O', 'DEGMEI'),
#  ('CCC(=O)C=CC(O)=CC(=O)OC', 'DEQZUV'),
#  ('COc1ccc(C=Nc2ccc(cc2)N=Cc2ccc(OC)c(OC)c2)cc1OC', 'DEWSUU'),
#  ('COc1ccc(cc1)C1NC2C(Cc3ccccc23)O1', 'DEXSIJ'),
#  ('CC(=N)NC(C)(C)C', 'DIBMIL'),
#  ('CC(C=C(C)c1ccccc1)C(=O)N1C(COC1=O)c1ccccc1', 'DIFVAQ'),
#  ('CC12CC3CC4CCC(=O)C=C4CC3CC1CCC2O', 'DIGRIV'),
#  ('COC(=O)C1CC2(C)N(C)C1(C)C(=O)NC2=C', 'DIGVUL'),
#  ('CCC(=O)C1(CC)NC(=O)C2(C)CC1C(=O)N2C', 'DIGWAS'),
#  ('CC(C)NC(O)=C(C#N)C(N)=O', 'DIJHIO'),
#  ('OC1(c2ccccc2)c2ccccc2C(O)(c2ccccc2)c2ccccc12', 'DIKCOP01'),
#  ('Oc1ccccc1C=NCCCCCN=Cc1ccccc1O', 'DIKXAX'),
#  ('OC(=O)c1c[n+]cc(c1)C(=O)[O-]', 'DINICA11'),
#  ('CN1N=NC2=C(N=CN2C1=O)C(N)=O', 'DIPGIS12'),
#  ('Cc1cccc(NC(=O)COc2ccc3ccc(O)cc3c2)n1', 'DIWPUV'),
#  ('CC1(C)CC(=NO)C(C)(C)C(C1)=NO', 'DIXLIF'),
#  ('CC1(C)CC(=O)C2=C(C1)N(C(=O)C(=C2)C(N)=O)c1ccccc1', 'DIYQEI'),
#  ('CN1N=NN(N)C1=N', 'DIZTOW'),
#  ('COC(=O)C(=O)OC', 'DMEOXA06'),
#  ('O=N(=O)c1cccc(c1)N(=O)=O', 'DNBENZ11'),
#  ('COc1ccc(CN2C(NC(C)=O)C(O)CCC2=O)cc1', 'DOCCUU'),
#  ('COc1ccc(CN2C(NC(=O)C(C)C)C(O)CCC2=O)cc1', 'DOCDAB'),
#  ('C(CCN1N=CN=N1)CN1C=NC(=N1)c1ccccn1', 'DOKQAW'),
#  ('C(CCN1C=NN=N1)CN1C=CN=N1', 'DOKQIE'),
#  ('ONC(=O)c1cccc(n1)C(=O)NO', 'DOMQUS'),
#  ('CC(=O)Nc1cccc(NC(C)=O)n1', 'DOPDAN01'),
#  ('COc1cccc(C=CC2OC(C)C(O)C2O)c1CO', 'DORKAX'),
#  ('CC1(C)CCC(C2CCC(C)(C)CC2=O)C(=O)C1', 'DOSCUK'),
#  ('CC1(C)CC(C2CCCCC2=O)C(=O)C=C1', 'DOSDEV'),
#  ('[N]=N=C(c1ccc(cc1)c1ccccc1)c1ccccc1C1OCCO1', 'DOYLEJ'),
#  ('C1CC=C2CCN(Cc3ccccc3)C2C1', 'DOYNIP'),
#  ('CCCC', 'DUCKOB04'),
#  ('CC(=O)Oc1ccc(cc1)C=Cc1ccc(OC(C)=O)cc1', 'DUDFIS'),
#  ('Cc1ccc(NCC(=O)NN)cc1', 'DUDGIT'),
#  ('C1CO1', 'DUFBOV11'),
#  ('OC(=O)c1cccc2CCCCc12', 'DUJKUP'),
#  ('CCOC(=O)C(=NOC)C(=O)c1ccc(cc1)N(=O)=O', 'DUNQOT'),
#  ('Nc1ccc(cc1)C(=O)OCCCOC(=O)c1ccc(N)cc1', 'DUSLIN'),
#  ('COc1ccc(C=CC(=O)c2ccc(cc2)N2CCCCC2)cc1', 'DUSWAQ'),
#  ('COc1cc(OC)c(C=NC2=C(C)C(=NO2)C)cc1OC', 'DUTBAW'),
#  ('CC1=CC(=O)N2C(=NC(=NC2=N1)C)N', 'DUTHEG'),
#  ('C1Cc2ccc(CCc3ccc1cc3)cc2', 'DXYLEN13'),
#  ('O=C(ON1C(=O)CCC1=O)C=[N+]=[N-]', 'EABXIO01'),
#  ('CCOC(=O)C1CC2(COC(N2C1=O)C(C)(C)C)C(=O)OC', 'ECUKAO'),
#  ('CC1(C)OC2OC3C4CCC4(C)CC3(OCc3ccccc3)C2O1', 'EDUKAP'),
#  ('COC(=O)C1(CC(=C)C2C3CCC(CCO3)C12)C(=O)OC', 'EFEQIQ'),
#  ('COC(=O)C1C2CC(C=C2)N1O', 'EGAFEY'),
#  ('CCC1C(O)CC2CCN3C2C1CCCC3=O', 'EGAMUV'),
#  ('CC(=C)C1CC=C2C(O)C(CC3(C)CC(=O)C(CC(=O)C1)O3)OC2=O', 'EHMVCT01'),
#  ('CC(NC(=O)c1ccccn1)C(O)=O', 'EJEXAT'),
#  ('CCNC(=O)NC(=O)CCC(C)C', 'EKAXOD'),
#  ('CCCNC(=O)NC(=O)CCC(C)C', 'EKECAY'),
#  ('CN1C(=CC(=C(C#N)C1=O)C)C', 'ELOJEV'),
#  ('CC1=NN(Cc2ccc3cc(CN4N=C(C)C=C4C)ccc3c2)C(=C1)C', 'EMACUR'),
#  ('COc1ccc2Oc3cc(C)cc(C)c3Cc2c1', 'EMOBOY'),
#  ('COc1ccc(c(C=O)c1OCc1ccccc1)N(=O)=O', 'EMOPIG'),
#  ('CN1CC(=Cc2cccnc2)C(=O)C(C1)=Cc1cccnc1', 'EMOROO'),
#  ('Nc1ccc(cc1)C1COC1', 'EMUDEW'),
#  ('Nc1ccc(CCc2ccc(O)cc2)cc1', 'ENALUA'),
#  ('COC(=O)c1c(N)c(C#N)c2c(CCC3=C2Nc2c(C)cccc32)c1C(=O)OC', 'ENIHAL'),
#  ('OC1C(OCC#C)OC2C1OC(=O)C2OC(=O)c1ccccc1', 'ENIJIV'),
#  ('CNC(=O)C1c2ccccc2C(=O)OC1(C)C', 'EPOMAY'),
#  ('CCOC(=O)C1(CO)ON=C(CC)C1c1ccccc1', 'EPOVEL'),
#  ('CN(C=O)c1cc(cc(c1O)C(C)(C)C)C(C)(C)C', 'ESEHAM'),
#  ('Cc1ccc(C)c(CC2CC3(C)CCCC2(O)O3)c1', 'ESUHAC'),
#  ('COC(=O)C1(CC(=O)c2c(O)cccc2O1)C1OC(=O)C=C1', 'ETADOT'),
#  ('OCC1=CN(N=N1)c1ccc(cc1)C(O)=O', 'EVATUR'),
#  ('COc1cc(ccc1OCC#C)C=NN=Cc1ccc(OCC#C)c(OC)c1', 'EVAVAZ'),
#  ('O=C1N2C=CN=C2C(=O)c2ccccc12', 'EVAWEE'),
#  ('CC1CNC(=O)CNC(=O)C(C)NC(=O)CC(C)O1', 'EVEDEO'),
#  ('O=C(C=CC1=CN(N=C1c1ccccc1)c1ccccc1)c1ccccc1', 'EVEKUM'),
#  ('N#CC1(CCCCC1)C#N', 'EVEVAD'),
#  ('NC(=O)CNC(=O)C=C', 'EVOGOM'),
#  ('O=N(=O)c1ccc(cc1)N#[C]', 'EVOSAJ'),
#  ('OC1C(=O)CC2c3ccccc3C1(CC=C)c1ccccc21', 'EXILON'),
#  ('c1ccc2c(c1)cccc2c1cccc2cccnc12', 'EXISEK'),
#  ('CC1(CC(=O)C2(O)C(=C1)C(O)C1OC(=O)C3(C)CCC4CC24C13)C=C', 'EYOGEF'),
#  ('CCC(C)C1N(OCc2ccccc2)C(=O)C(C(C)CC)N(OCc2ccccc2)C1=O', 'EYOLAG'),
#  ('COC(=O)C12CC(C=C)C(N)C1c1ccccc1NC2=O', 'EZAZEL'),
#  ('CC(NC(=O)COc1cccc2ccccc12)C(=O)NCC(O)=O', 'FACLIG'),
#  ('CC(C)(C)C1=CC(C=C(C1=O)C(C)(C)C)=C1C=C(C(=O)C(=C1)C(C)(C)C)C(C)(C)C',
#   'FADDOD03'),
#  ('CNC(=O)C(NC(C)=O)=CC', 'FADWEO'),
#  ('OC(=O)C1CC21CC12CC21CC2', 'FAFDEW'),
#  ('OC1C(CCCC1=Cc1ccccc1)CN1CCOCC1', 'FALSAN'),
#  ('O=C1CCC23CCCN2C(=O)CCCC3C1', 'FARJAK'),
#  ('[N+]C(Cc1ccc(O)cc1)C(=O)[O-]', 'FAZHET01'),
#  ('CC1CC2C(C3C=CCC4CCC(O)C14C3=O)C2(C)C', 'FEJCIH'),
#  ('COc1ccc(NC=O)cc1', 'FELVIC01'),
#  ('COC1=C(N=CN1C)N(=O)=O', 'FICDOK01'),
#  ('CC1CCCC2(C)CC3OC(=O)C(=C)C3C3OC123', 'FIFQIU01'),
#  ('CCCC1=Cc2cccnc2N1', 'FIXMUV'),
#  ('O=C1N(Cc2ccccc2)C(=O)c2ccccc12', 'FOLBUE01'),
#  ('OC(=O)C1=CC=CO1', 'FRANAC04'),
#  ('CC(C)(OO)c1ccncc1', 'FUBWAB'),
#  ('CC1(C)OC2OC(C(O)C2O1)C(=O)C1CC2CC1C=C2', 'FUBZAE'),
#  ('N#CCc1ccccc1CC#N', 'FUGWOU'),
#  ('CCOC(=O)C(N1N=C(C)C=C1C)N1N=C(C)C=C1C', 'FUHZAK'),
#  ('CC1=NC=CN1', 'FULPIM'),
#  ('OC1CCCCc2ccc(Oc3cc(CC1)ccc3O)cc2', 'FUMFUP'),
#  ('CC(C(=O)c1ccc(OCc2ccccc2)cc1)c1ccccc1', 'FUNZAQ'),
#  ('COc1cc(CC=CCc2cc(OC)c(O)c(C=O)c2)cc(C=O)c1O', 'FUPTOA'),
#  ('Oc1c(CC=CCc2cccc(C=O)c2O)cccc1C=O', 'FUPTUG'),
#  ('CC(C)COc1cccc(Nc2ccccn2)c1', 'FUTCED'),
#  ('O=C(Nc1ccccc1)Nc1ccc(cc1)N(=O)=O', 'FUWJAJ'),
#  ('CC(Nc1ccc(cn1)N(=O)=O)c1ccccc1', 'FUXZIH01'),
#  ('O1C=CC2C1OC1OC3OC=CC3C21', 'GACGEY'),
#  ('CC1(COC(=O)C21OC(=CC2=O)c1ccccc1)C=C', 'GAKPUE'),
#  ('CCOc1ccc(cc1)N(=O)=O', 'GAKQEP'),
#  ('Cc1ccc2N=C3N(CCC3(O)C(=O)c2c1)c1ccccc1', 'GANSUK'),
#  ('C1CCc2c(C1)nc(cc2c1ncccn1)c1ccccc1', 'GANVOH'),
#  ('O=C1Cc2c1c1C(=O)Cc1c1C(=O)C(=O)c21', 'GEFBAV'),
#  ('c1ccc(cc1)c1c2cccc3c4ccccc4c(c23)c2c(c3ccccc3)c3cccc4c5ccccc5c(c34)c12',
#   'GEGQUF'),
#  ('CC1=CN(CC(N)=O)C(=O)NC1=O', 'GEHVOF'),
#  ('OC(=O)c1ccc2CCC(=O)c2c1', 'GEJCUU'),
#  ('CC(=O)C(Cc1ccc(CC(C(C)=O)C(C)=O)cc1)C(C)=O', 'GEJDAB01'),
#  ('CC(=O)CCC1C(=O)C=C2C(C)(C)CCCC12C', 'GEKDAC'),
#  ('O=C1OCCCOC(=O)c2ccc(cc2)C(=O)OCCCOC(=O)c2ccc1cc2', 'GILGAK'),
#  ('CN1c2ncc(C)cc2C(=C1c1ccccc1)CC(C)(C)C', 'GILXUV'),
#  ('C(CCN(Cc1ccccn1)Cc1ccccn1)CN(Cc1ccccn1)Cc1ccccn1', 'GIMTEC'),
#  ('CC(=O)c1ccc(O)cc1O', 'GINCAI01'),
#  ('Cc1cc(nc(N)n1)c1ccncc1', 'GIRNOL'),
#  ('Nc1ccc(cn1)C#Cc1cccnc1', 'GIRPED'),
#  ('O=C(Nc1ccccc1)Oc1ccc(cc1)N(=O)=O', 'GISTAE'),
#  ('OCC1OC(O)C(O)C(O)C1O', 'GLUCSE02'),
#  ('[N+]CC(=O)[O-]', 'GLYCIN69'),
#  ('[N+]CC(=O)NCC(=O)[O-]', 'GLYGLY19'),
#  ('Cc1ccc(Oc2cnc3ccccc3n2)cc1', 'GOFVON'),
#  ('[N-]=[N+]=Nc1ccccc1c1ccccc1', 'GOVZUM01'),
#  ('COc1cccc2C(O)CC(=C)c12', 'GUCJUK'),
#  ('CC1CC(O)C(N(=O)=O)C(O)(C1C(=O)c1ccccc1)c1ccccc1', 'GUCNIC'),
#  ('COC(=O)C([n+]1ccccc1)=C(C(=O)OC)[C-]1C(=O)COC1=O', 'GUGJUO'),
#  ('CCOC(=O)CC1=NN=NN1CCNC(=O)OC(C)(C)C', 'GUGKAV'),
#  ('COC(=O)C1C(C(=O)OC)C21C(=O)CC(C)(C)CC2=O', 'GUHCUI'),
#  ('c1nc2ccc3c4ccc5ncnc6ccc(c7ccc(n1)c2c37)c4c56', 'GUSKEL'),
#  ('COC(=O)C1(CC2C(C1)C(=C(C)C2c1ccccc1)C)C(=O)OC', 'GUVNOB'),
#  ('COCCCN1C(=O)c2cccc3cccc(C1=O)c23', 'GUWDUX'),
#  ('O=C(C1C2CCC1C2(c1ccccc1)c1ccccn1)c1ccccc1', 'HADLOO'),
#  ('COC(=O)C1=C(C(=O)OC)C2(c3ccccc3)c3ccccc3C1c1ccccc21', 'HADMAA01'),
#  ('COc1ccc(O)c(C=NC2=C(C)N(C)N(C2=O)c2ccccc2)c1', 'HAHTAN'),
#  ('Cc1cc(C)c2ccc3c(C)cc(C)c4ccc1c2c34', 'HAJJOT'),
#  ('C1=CN2N=CN=C2N=C1', 'HAMGOT'),
#  ('O=C(NC1CCCCC1)C1=Cc2ccccc2OC1=O', 'HAMVEX'),
#  ('Cc1cc(O)c2c(O)c(C(C)=O)c(C)cc2c1', 'HEKWAV01'),
#  ('CCCCNc1cc(cc(C)[n+]1[O-])N(=O)=O', 'HENCEJ'),
#  ('CCCCCCC', 'HEPTAN02'),
#  ('CC1(C)COC(=N1)c1ccccc1N=C(c1ccccc1)c1ccccc1O', 'HERMAT'),
#  ('CC(O)CN1CCNCCN(CCN(CC1)CC(C)O)CC(C)O', 'HESKUM'),
#  ('OC12CCCCC1(CCC#N)CCC(=O)C2', 'HEWSIM'),
#  ('CCCCCC', 'HEXANE01'),
#  ('COC(=O)C(=Cc1ccc(C)cc1)C#N', 'HEXXEO'),
#  ('O=C(NCCCCCC#N)NCCCCCC#N', 'HEZSUA'),
#  ('CC1(C)CC2OC2(C)CCC2OC2(C)C(O)C2OC12', 'HIBBOK'),
#  ('Cc1ccc(cc1)C=C1C=Cc2ccccc12', 'HIHBAC'),
#  ('O=C1Oc2ccccc2O1', 'HIRSUX'),
#  ('O=C1OC2CCC1C1COCC21', 'HIXJEE'),
#  ('CC1(C)OC2C(O)COC(OCc3ccccc3)C2O1', 'HIYRUD'),
#  ('O=N(=O)[N-][N+]1=NNC=C1', 'HIZTEQ'),
#  ('CC1=CC(=O)OC2CCCCC12C(=O)OC(C)(C)C', 'HOCSOI'),
#  ('O=N(=O)C1=NC=CN1CCOCCOCCN1C=CN=C1N(=O)=O', 'HODWAZ'),
#  ('CC(=O)c1ccc(cc1)C#CC#Cc1ccc(cc1)C(C)=O', 'HOJVIM'),
#  ('C1Cc2ccccc2C2N(Cc3ccccc3)Cc3ccccc3N12', 'HOPNIK'),
#  ('OC(=O)c1ccccc1C(=O)OCCCCOC(=O)c1ccccc1C(O)=O', 'HOQXER'),
#  ('NN1C=CC=N1', 'HOYMAJ'),
#  ('Cc1nc(N)nc2ccccc12', 'HUCBIR'),
#  ('CCOc1ccc(cc1)C1C(=C(C)NC(=C1C(=O)OC)C)C(=O)OC', 'HUDHEU'),
#  ('N#Cc1cnc2ccccc2n1', 'HUDZAI'),
#  ('NNC(=O)COc1ccccc1', 'HUFDOC'),
#  ('COC(=O)COC(=O)c1ccc2C(=C(Oc2c1)C(=O)OC)O', 'HULKII'),
#  ('CC1CCC23OC(=O)C4(O)OC(CC124)C1(O)C(=O)OCC31C', 'HUNNOU01'),
#  ('CC1(C)COC(=O)C=C1C(O)=O', 'HUXJOZ'),
#  ('CC1=CC(C)(C(=C1C)C)C1(C)C=C(C)C(=C1C)C', 'IBINAI01'),
#  ('O=C1OCCCCCCCCCCC#Cc2cccc1c2', 'IDOPUM'),
#  ('CC1(CC(C1)C(=O)C1=Cc2c(O1)ccc1ccccc21)c1ccccc1', 'IDUNIF'),
#  ('CCC1C2CCCCN3CCC(C4C(C)C(=O)OC14)C23', 'IFEBOL'),
#  ('CC(C(O)c1ccccc1)N(C)Cc1cccnc1', 'IFOQIE'),
#  ('O=C1C2CCN(CC2)C1=CC1=CN(Cc2ccc(cc2)C#N)c2ccccc12', 'IFUNON'),
#  ('CON(OC(C)=O)C(N)=O', 'IHANOV'),
#  ('OC1=C(Oc2ccccc2C1=O)C1=CC=CO1', 'IJUCEW'),
#  ('Oc1ccccc1C1(C2CC3CC(C2)CC1C3)N1C=CN=C1', 'IJUYUI'),
#  ('CC(C)CN1C=Nc2c(NN)nc3ccccc3c12', 'IKABIG'),
#  ('COC(=O)C(C)(C(C#N)c1ccccc1)c1ccccc1', 'IKADAZ'),
#  ('OC1OC23C4C5CCC(C4OC42CC2CCC4C=C2)C3C15', 'IKUZOE'),
#  ('CCCCNC1=CC(=C2C(=O)C(=CC(=C2C1=O)O)NCCCC)O', 'ILISEB'),
#  ('Cc1cc([N+]#[C-])c(C)cc1[N+]#[C-]', 'IMIJUJ'),
#  ('OC(=O)CC1=CNc2ccccc12', 'INACET04'),
#  ('Cc1c(c(O)cc2C(=O)c3cccc(O)c3C(=O)c12)C(=O)OC(C)(C)C', 'IPOKAA'),
#  ('CC(C)c1ccc(O)cc1', 'IPRPOL01'),
#  ('[N+]CC(O)C(=O)[O-]', 'IPUMUC'),
#  ('C(CCN1N=CN=N1)CN1N=CN=N1', 'IQEJAP'),
#  ('CCOC(=O)c1ccnc(c1)c1cc(ccn1)C(=O)OCC', 'IQOWUG'),
#  ('COc1ccc(C(O)=O)c(OC)c1', 'ISUQUI'),
#  ('CC(C)c1cc(C(C)C)c(C(O)=O)c(c1)C(C)C', 'ITEGEU'),
#  ('N#Cc1cccc(c2ccccc2)c1C#N', 'IVASEE'),
#  ('CC1(C)CC(C)(C)C2=C1C(=O)C1=C(C2=O)C(C)(C)CC1(C)C', 'IVIQIO'),
#  ('Cc1ccc(CNc2ncnc3NC=Nc23)cc1', 'IVOGOQ'),
#  ('CNC1CC2=C(C)C(=O)OC32CC2(C)C(CCC12C)N3', 'IWOMEN'),
#  ('NC1=NC2OC(CO)C(O)C2O1', 'IWUGEM'),
#  ('NC1=NC2OC(CO)C(O)C2O1', 'IWUGIQ01'),
#  ('Cc1ccc(cc1C)N=C1c2ccccc2c2ccccc12', 'IXATUW'),
#  ('CC(N1C(=O)c2ccccc2C1=O)C(O)=O', 'IZAMAX'),
#  ('CC1=CN(C2CC3(O)COCOCC3(CO)O2)C(=O)NC1=O', 'IZUXAC'),
#  ('CC1CCC2(O)C(C1)CC(=O)OC2(C)C', 'JASJET'),
#  ('OCC(O)C1OC2OC3(CCCCC3)OC2C1O', 'JAVZIQ'),
#  ('COc1ccc(cc1)c1cc(ncn1)c1cc(ncn1)c1ccc(OC)cc1', 'JAWFOD'),
#  ('O=C1N(c2ccccc2)C(=NC1=Cc1ccccc1)c1ccccc1', 'JAXKAV'),
#  ('CCC', 'JAYDUI'),
#  ('CC(=O)c1ccc2ccccc2c1O', 'JEDZIC'),
#  ('COc1cccc(O)c1C(C)=O', 'JEDZOI'),
#  ('CC(C)C(C(C#N)c1ccc2OCOc2c1)N1CCOCC1', 'JEMPIB'),
#  ('CC(C)C(N)CO', 'JESTAD'),
#  ('O=C1CC2OC(CO1)C=C2', 'JINZAI'),
#  ('COC(=O)NNC(=O)OC', 'JIPFAQ'),
#  ('COC(=O)C1C(C)C(=O)C=C1C1=CC=CO1', 'JISJAX'),
#  ('COc1ccc(OC)c2C3C(=CCC4=C3C(=O)C=CC4=O)CCc12', 'JISXOZ'),
#  ('CN(C)C(N(C)C)=C(N(C)C)N(C)C', 'JOJWOU03'),
#  ('CC1(C(=O)Nc2ccccc12)C(=O)Oc1ccccc1', 'JOKKUQ'),
#  ('COC(=O)C1(C(=O)N(Cc2ccccc2)c2ccccc12)c1ccccc1', 'JOKLEB'),
#  ('CC12CC(=O)CC1OC(=O)C=C2', 'JULFUR'),
#  ('COC(=O)C1CC(NC(=O)N1)C(=O)OC', 'JULRIR01'),
#  ('c1cc2cccc3c4cc5cccc6cccc(c4cc(c1)c23)c56', 'KAGGEG'),
#  ('CCOC(=O)C(CC(=O)Nc1ccccc1)C(=O)c1ccccc1', 'KAWPAA'),
#  ('COc1ccc(cc1)C1=C(OC)C(=O)c2c(O)cc(OC)cc2O1', 'KAYSAE01'),
#  ('CC(=O)OC1COC(C=C1)C(=C)C(=C)C1OCC(OC(C)=O)C=C1', 'KEBFIH'),
#  ('CC(C)c1cccc(C(C)C)c1N=C(C)c1ccccn1[O]', 'KEDKAG01'),
#  ('CC1C2C(CCCN3C2CCC3=O)OC1=O', 'KEGYIF'),
#  ('O=C(C1=CC=CN1)c1ccccn1', 'KELDUB'),
#  ('COC1=NC(C=C1)=C(C1=CC=CN1)c1ccc(cc1)C#N', 'KEYJUU'),
#  ('COc1ccccc1C=C1CCC(=C1)c1ccccc1', 'KIDTIB'),
#  ('CCC(Nc1ccccc1O)=CC(=O)c1ccccc1', 'KIJPEZ'),
#  ('COc1ccc(c(O)c1)C(=Nc1ccccc1NC(C)=O)c1ccccc1', 'KOFVAD'),
#  ('Cc1cc2OC(=C(c3ccccc3)c2cc1C)c1ccccc1', 'KOKRUY'),
#  ('O=N(=O)C1=CNC=N1', 'KOMHAV01'),
#  ('CC(C)C12OC1C1OC31C1(C)CCC4=C(COC4=O)C1CC1OC31C2=O', 'KORVES02'),
#  ('OCC1CCCC21CCCC(CC(O)c1ccccc1)N2O', 'KUKFUS'),
#  ('CN1C(=O)c2ccccc2C(O)(CC2=C(C)N=C(C)O2)C1=O', 'KUSHUC'),
#  ('CC1=NOC(=C1C)N=Cc1ccccc1O', 'KUSTAU'),
#  ('CNc1ccncc1', 'KUTBOR'),
#  ('CCC(=O)N1N=C(N=NC1C)c1ccc(OC)cc1', 'KUVDOV'),
#  ('OC(=O)CC1CCC(=O)CC1', 'KUZQIG'),
#  ('CC(C)N=C1N(C(C)C)C(=NC(C)C)N1C(C)C', 'LADKUY'),
#  ('NC1=NC2OC(CO)C(O)C2O1', 'LAKDOR'),
#  ('COc1ccc(C(C)=O)c(O)c1', 'LAMNAP01'),
#  ('COC(=O)C(C)(O)NC(C)=O', 'LAQSOM'),
#  ('CCOC(=O)CC1CCCC1(NC(C)c1ccccc1)C(N)=O', 'LEBNUC'),
#  ('CC(=O)ON=C(C1=CNC=N1)N(=O)=O', 'LEFFEI'),
#  ('CC(=O)OC1C=CCC(NC(=O)OC(C)(C)C)C1OC(C)=O', 'LEMFUF'),
#  ('COC1(OC)N(C(=O)C1(OC)OC)C1=C(C)N(C)c2ccccc12', 'LEMKEU'),
#  ('COc1ccc(N2C(=O)C(OC)(OC)C2(OC)OC)c(OC)c1', 'LEMKIY'),
#  ('CCOC(=O)C1=C2N(C=Cc3ccccc23)C2=C1C(=O)c1ccccc1C2=O', 'LIBZUS'),
#  ('CCc1ccc(cc1)C(=C=C=C=C=C(c1ccc(CC)cc1)c1ccc(CC)cc1)c1ccc(CC)cc1', 'LIJGIV'),
#  ('CC(=O)N1CC(=O)CN1C(C)=O', 'LILLAU'),
#  ('C1CN2CCN3CCN1C23', 'LINMOK'),
#  ('O=C(CN1C=CN=C1N(=O)=O)NCc1ccccc1', 'LIVWET'),
#  ('CC(=O)c1cc(ccc1O)C#N', 'LIWFUT'),
#  ('O=N(=O)c1cc2Cc3ccc4ccccc4c3c2c2ccccc12', 'LIZBUS'),
#  ('CC(=O)c1ccccc1NCCC(O)=O', 'LOHTAE'),
#  ('[N+]C(CO)C(=O)[O-]', 'LSERIN20'),
#  ('[N+]C(C(C)O)C(=O)[O-]', 'LTHREO03'),
#  ('CC(C)OC12C=NOc3cccc(C=CC1=O)c23', 'LUDJOK'),
#  ('COC(=O)C(C)(CC=C)C(OC(=O)c1ccc(cc1)N(=O)=O)C(C)C', 'LUDMAZ'),
#  ('c1ccc2c(c1)c1cc3c4ccccc4c4cc2c2cc4c4ccccc4c3cc1c1ccccc21', 'LUGJEC'),
#  ('CC(c1ccccc1)C1(O)N(C)C(=O)c2ccccc12', 'LUMKEK'),
#  ('COc1cc2c(C)c3cc(OC)c(OC)cc3c(C)c2cc1OC', 'LUMLAH'),
#  ('OC12C(CNC(=O)c3ccccc13)C13CC4CC(CC(C4)C21)C3', 'LUQSIA'),
#  ('COc1ccc2c(CCC3C4CCC(OC(=O)C56CCC(C)(C(=O)O5)C6(C)C)C4(CC=C23)C(=O)OC(C)(C)C)c1',
#   'LUSGIQ'),
#  ('CC(C)C1CC=C2C(O)C3CC(=O)C=CC3(C)CCC12C', 'LUSJIS'),
#  ('CN1C(=O)C(C)(N=C(c2ccccc2)c2cc(C)cc(C)c12)C#N', 'LUTGAJ'),
#  ('CC1(C)C2CCC(O)(C2)C1=O', 'LUVCOU'),
#  ('O1C=CC=C1C1=CC=C(O1)C1=CC=C(O1)C1=CC=C(O1)C1=CC=C(O1)C1=CC=CO1', 'LUVYIL'),
#  ('O1C=CC=C1C1=CC=C(O1)C1=CC=C(O1)C1=CC=CO1', 'LUVYOR'),
#  ('O=C1N2c3ccccc3N=C2c2ccc3c4ccc5C(=O)N6c7ccccc7N=C6c6ccc(c7ccc1c2c37)c4c56',
#   'MAMHEO'),
#  ('Nc1cccc(O)c1', 'MAMPOL02'),
#  ('CC(=O)OCC1OC2C(OC(C)=O)C(CN(C2C(OC(C)=O)C1OC(C)=O)C(=O)OC(C)(C)C)OC(C)=O',
#   'MANJIV'),
#  ('Cc1c(N)cccc1O', 'MATBAL'),
#  ('Nc1cccc2ccc(O)cc12', 'MATCEQ'),
#  ('C1CC2OC1C1C3OC(C=C3)C21', 'MAYXEP'),
#  ('C1CC2OC1C1C3OC(C=C3)C21', 'MAYXIT'),
#  ('NC(=O)c1cc[n+]([O-])cc1', 'MEGDAE'),
#  ('COc1ccccc1C#CC(O)=O', 'MEKMIZ'),
#  ('CNC=C(C(C)=O)C(C)=O', 'MEMXEI'),
#  ('COC(=O)c1ccc(NC2CCCOC3OCCC23)cc1', 'MERHAS'),
#  ('COC(=O)c1ccc2NC(CCCO)C3CCOC3c2c1', 'MERHEW'),
#  ('COC(=O)C(=CN)C#N', 'MIGWUV'),
#  ('Nc1cccc(c1)N(=O)=O', 'MNIANL02'),
#  ('COC(=O)c1ccc(CN2C=C(C=C3NC(=O)NC3=O)c3ccccc23)cc1', 'MOKNEG'),
#  ('CC1C=CCC2(C)C1C(=O)c1ccccc1C2=O', 'MORZUP'),
#  ('CC1=CC(=O)C2(C)C3CC(C=C3)C2C1=O', 'MOSBAY'),
#  ('Cc1ccc(cc1)C1=NCCN1', 'MOSJOU'),
#  ('COc1ccc(cc1)C1OC(c2cc(OC)c(OC)c(OC)c2)C(O1)(C#N)C#N', 'MOVHEL'),
#  ('CC1(C)C2COC(O2)(c2ccccc2)c2ccccc12', 'MOVJUD'),
#  ('CC1(O)CC2OC(=O)C3C2C1C3=C', 'MOVNAN'),
#  ('Cc1cc(nc2ccccc12)C(N)=O', 'MQUCXA11'),
#  ('CC(=CC1=CC=CO1)N(=O)=O', 'MUBLUR'),
#  ('COc1cc(cc(c1O)N(=O)=O)C(C)=O', 'MUCDOE'),
#  ('NC1=[N+]([O-])CC(O)CC1', 'MUDZER'),
#  ('COc1cc(CO)c(O)c(CO)c1', 'MUGNEH'),
#  ('CC1C=CC(COC(=O)c2ccc(cc2)N(=O)=O)ON1C(=O)OC(C)(C)C', 'MUJCEA'),
#  ('CCCN1C(CC)OC2CC3CCC2(C1=O)C3(C)C', 'MUJGEE'),
#  ('COc1cc(CC2COC(C2CO)c2ccc(O)c(OC)c2)ccc1O', 'MUKBOK'),
#  ('CNC(=O)c1ccc2ccccc2n1[O]', 'MULMUC'),
#  ('CCOC(=O)N1C(C(C(=O)c2ccccc12)c1ccccc1)c1ccccc1', 'MUMVOG'),
#  ('OCC1OC(CC1O)c1ccccc1O', 'MUYDAL'),
#  ('OCC1OC(CC1O)c1ccccc1', 'MUYDEP'),
#  ('OCC1(O)COC(O)(CO)CO1', 'NADQAL'),
#  ('OCC(=O)CO', 'NADQOZ'),
#  ('CC1CC(=O)C2COC(C)(C)C3CCC1(C)CC23', 'NALNAQ'),
#  ('CC1=CN2C3C(COCc4ccccc4)OC(O)C3OC2=NC1=O', 'NANRIE'),
#  ('OC(C(OC1CCCC(=O)CC1)c1ccccc1)c1ccccc1', 'NAWVOX'),
#  ('OC(=O)c1ccccc1N(=O)=O', 'NBZOAO04'),
#  ('COc1ccc(C=NCCN=Cc2ccc(OC)c(OC)c2)cc1OC', 'NEFNUI01'),
#  ('C1C2CC3CC1CC(C2)(C3)C#Cc1c2ccccc2c(C#CC23CC4CC(CC(C4)C2)C3)c2ccccc12',
#   'NEKFAL'),
#  ('Cc1c2CC3=C(CC(C)(C)CC3=O)Oc2c(C)c2N3CCCC3Oc12', 'NEPVAG'),
#  ('CCC1=CNC(=C1CC)C(=O)C(O)=O', 'NESTIP'),
#  ('COC(=O)CC(C)C1(C)CCc2c(ccc3ccccc23)C1=O', 'NEYQOY'),
#  ('C1CC2(CC2)C=C1', 'NICRIA'),
#  ('CN(C)c1ccc(C=CC(=O)c2cccc(c2)N(=O)=O)cc1', 'NIFDOW'),
#  ('CC(C)(C)c1cc(CN2CCN(CC2)Cc2cc(cc(c2O)C(C)(C)C)C(C)(C)C)c(O)c(c1)C(C)(C)C',
#   'NIRNOS'),
#  ('NC(=O)c1cccc(CN2C=CC=N2)c1', 'NIWWIA'),
#  ('CC1=NN(Cc2cccc(c2)C(N)=O)C(=C1)C', 'NIWWOG'),
#  ('Cc1ccc(cc1)N=Cc1ccc(cc1)N(=O)=O', 'NMBYAN01'),
#  ('CC(C)c1cccc(C(C)C)c1N=Cc1ccc2ccccc2n1[O]', 'NOHROS01'),
#  ('CC(=O)Nc1cccc(C)c1', 'NOJJIG'),
#  ('CCOC(=O)C1(CC2=C(N3CCCCC13)c1ccccc1OC2=O)C#N', 'NOKHEB'),
#  ('CCOC(=O)C1(C)C(=CC(Cc2ccccc2)C1(C)O)C', 'NONBUO'),
#  ('CC1CC(=O)OC(C)C(O)C=CC(=O)OC(C)C(O)C=CC(=O)O1', 'NOQTES01'),
#  ('N#Cc1ccc(cc1)C=NCCN=Cc1ccc(cc1)C#N', 'NOQYEY'),
#  ('CCOc1cccc(C=NCCCCN=Cc2cccc(OCC)c2O)c1O', 'NORCON'),
#  ('COc1ccc(cc1)C1=NCCN1', 'NORHEI'),
#  ('OCCO', 'NOZKES02'),
#  ('O=C1N(CCc2ccccn2)C(=O)c2ccccc12', 'NUNBUU'),
#  ('NNC(=O)C(=O)NO', 'NUPTIC'),
#  ('O=C1CC2CCCC(C2)O1', 'NUQPIZ'),
#  ('NNC(=O)c1ccc(N)cc1', 'NUVXIM01'),
#  ('C(N1C=NN=N1)c1ccc(cc1)c1ccc(CN2C=NN=N2)cc1', 'OBAREQ'),
#  ('C#CN(c1ccccc1)c1ccc(cc1)N(C#C)c1ccccc1', 'OBUBUK'),
#  ('C1CC2CC1C1=C2c2ccccc2C2=C(C3CCC2C3)c2ccccc12', 'OBUKAZ'),
#  ('C(CCOc1cc(nc(c1)c1ccccn1)c1ccccn1)COc1cc(nc(c1)c1ccccn1)c1ccccn1',
#   'OCEJIR'),
#  ('O=N(=O)N1CN(CN(CN(C1)N(=O)=O)N(=O)=O)N(=O)=O', 'OCHTET13'),
#  ('O=C1OCC2CC12C#N', 'OCIQOH'),
#  ('CCCCCCCC', 'OCTANE01'),
#  ('O1C(=CN=C1c1ccccc1)C=CC1=CN=C(O1)c1ccccc1', 'OCURUB'),
#  ('O=C1C(=C2c3ccccc3c3ccccc3C2=C1c1ccccc1)c1ccccc1', 'ODEJOX'),
#  ('CNC(=O)C(C)N(C)C(C)=O', 'ODETOH'),
#  ('CCOC(=O)C(=O)OCC', 'ODEVUQ'),
#  ('CC(C)OC(=O)C(=O)OC(C)C', 'ODEXEC01'),
#  ('CCCCOC(=O)C(=O)OCCCC', 'ODEXOM01'),
#  ('CCOC(=O)C(=O)OC', 'ODEZEE01'),
#  ('CC(=O)N(C(=O)Nc1ccc(C)cc1)c1ccc(C)cc1', 'OFELIV'),
#  ('C1CN=C(N1)c1ccc(cc1)C1=NCCN1', 'OGEQIB'),
#  ('OCC1(O)OCC(O)C(O)C1O', 'OGETAW'),
#  ('COC1OCC(O)C(O)C1O', 'OGETEA'),
#  ('CC1CCC2(C)C(CCC=C2C)C1(C)CC=O', 'OHIPUR'),
#  ('O=C1N2c3ccccc3N=C2c2ccc3C(=O)N4c5ccccc5N=C4c4ccc1c2c34', 'OHIXUY'),
#  ('CC1C2CCC(C)(O2)C2CC(C)(C)C(C#N)C2C1=O', 'OHOWOX'),
#  ('O=N(=O)c1ccc2NC34CCCCC3(Nc3ccc(cc3O4)N(=O)=O)Oc2c1', 'OHUJOQ'),
#  ('C1CC2CCC1C1C2=C2C3CCC(CC3)C2=C1c1ccccc1', 'OHUYIZ'),
#  ('O=C(OCCC=CCCOC(=O)c1ccccc1)c1ccccc1', 'OJEPUO'),
#  ('CC(O)C1CN(C)C(=O)C1NC(=O)OC(C)(C)C', 'OKEDOY'),
#  ('COc1ccc(C=NO)c(C)c1C', 'OKUHAD'),
#  ('CC1C(OCC2=CN(CCCC(=O)N1C)N=N2)c1ccccc1', 'OLATUR01'),
#  ('CC1C(OCC2=CN(Cc3cccc(c3)C(=O)N1C)N=N2)c1ccccc1', 'OLAVAZ'),
#  ('O=C1CCc2ccccc2C21CC2c1ccc2ccccc2c1', 'OLAVUS'),
#  ('O=N(=O)c1ccc(NN=C2C3CC(C=C3)C3CCCC23)c(c1)N(=O)=O', 'OLAWAZ'),
#  ('Cc1cc(C)c2Oc3c(cc(C)c4Oc5c(C)cc(C)cc5c34)c2c1', 'OLOXUJ'),
#  ('Cc1ccc2NC3=C(CCC(=CC4=CC=CO4)C3=O)c2c1', 'OMABAG'),
#  ('COC(=O)C(=C)C1COC(OO1)c1ccc(cc1)C#N', 'OMEHIY'),
#  ('O=N(=O)C1=CON=C1c1ccccc1', 'OMEJOG'),
#  ('CC1(C)C2=CCC3CCCC(=O)C3(C=O)C2CCC21OCCO2', 'OMEQON'),
#  ('C1CCC(=CC1)C1(C#Cc2ccccc2)C2CC=CC12', 'ONEMOK'),
#  ('CN(C)C(=NN=C(N(C)C)N(C)C)N(C)C', 'ONUMAM'),
#  ('CN1CCN(C)C1=NN=C1N(C)CCN1C', 'ONUMEQ'),
#  ('O=C1CCC21C=CC1COC2O1', 'OPIKUU'),
#  ('COc1c(c(O)c(c(O)c1N(=O)=O)N(=O)=O)N(=O)=O', 'ORAVUZ'),
#  ('CCOC(=O)C(=Cc1ccccc1)N1C=NC2=C1C(=O)N(C)C(=O)N2C', 'OWAHAW'),
#  ('CCOC(=O)C1CN(Cc2ccccc2)C(=O)C1O', 'OXESEQ'),
#  ('COC(=O)C1(N(CC(CC=C)C1(C)O)C=O)C(=O)OC', 'OXODIP'),
#  ('C1C(C=Cc2ccccc2)C1(c1ccccc1)c1ccccc1', 'OYEHAC'),
#  ('CC(C)(O)CN1c2cnc3ccccc3c2N=C1c1ccccc1', 'OYEXIA'),
#  ('CC1=CC(C=CC1C(O)=O)C(O)(c1ccccc1)c1ccccc1', 'OZEBEB'),
#  ('OC(c1ccccc1)c1ccccc1c1ccccc1C(O)c1ccccc1', 'OZIVOJ'),
#  ('CC(C)C1NC(=O)N(CC2CCCCC2)C1=O', 'PAXTOY'),
#  ('OC(=O)C(O)=Cc1ccc(cc1)N(=O)=O', 'PENPUU'),
#  ('Cc1ccc(cc1)C=C(O)C(O)=O', 'PENQAB'),
#  ('COc1ccc(cc1)C=C(O)C(O)=O', 'PENQEF'),
#  ('CCCCC', 'PENTAN01'),
#  ('COC(=O)C(N1C(C(N)C1=O)c1ccccc1)c1ccccc1', 'PENXEL'),
#  ('O=N(=O)OCC(CON(=O)=O)(CON(=O)=O)CON(=O)=O', 'PERYTN12'),
#  ('OCC(CO)(CO)CO', 'PERYTO12'),
#  ('CC1N=C(N)OC1c1ccccc1', 'PEVHEE'),
#  ('CC1(C)COC(=N1)C1(CCCc2ccccc12)c1ccccc1', 'PEXKOT'),
#  ('COC(=O)OC1C2CC3(C(C=C2c2ccccc2)C13)c1ccccc1', 'PEZVIA'),
#  ('O=C1N(c2ccccc2)C(=O)N1c1ccccc1', 'PHCYND03'),
#  ('OC(=O)c1ccccc1C(O)=O', 'PHTHAC04'),
#  ('Nc1nc(NC2CC2)c2N=CN(C3CC(O)C=C3)c2n1', 'PIDBUA'),
#  ('OC(=O)CC1CCC2CC(=O)CCC2C1', 'PIDGIT'),
#  ('CC(=O)CCC1=C2NC(=O)CCC2CCC1', 'PILHAU'),
#  ('OC(=O)C1=CC=CNC1=O', 'PIMBAP04'),
#  ('OC(=O)CCCCCC(O)=O', 'PIMELA07'),
#  ('OC1COC2C(COC12)ON(=O)=O', 'PIMKOO'),
#  ('O=C1c2cccnc2c2ncccc12', 'PINNOP02'),
#  ('O=C(Nc1cccnc1)c1ccc(cc1)C(=O)Nc1cccnc1', 'PITFOO01'),
#  ('OC(Cc1ccccc1)C(O)=O', 'PLACTA01'),
#  ('CC(N1CC(CC1=O)C(O)CO)c1ccccc1', 'POFQEH'),
#  ('N#Cc1ccc(cc1)C=NCCCCN=Cc1ccc(cc1)C#N', 'POFRAE'),
#  ('N#Cc1ccc(cc1)C=NCCCCN=Cc1ccc(cc1)C#N', 'POFRAE01'),
#  ('CC1=C(C(O)=O)C(=O)Nc2ccccc12', 'PONNAI'),
#  ('CN1C(=O)C2=C(NN=C2O)c2ccccc12', 'PONNIQ'),
#  ('COc1ccccc1C=NNc1ccc(cc1N(=O)=O)N(=O)=O', 'PONTIW'),
#  ('COc1cc2COCc3c4COCc4ccc3c2c(OC)c1OC', 'POPYID'),
#  ('CC(CC#N)N(Cc1ccccc1)Cc1ccccc1', 'PORVEY'),
#  ('COC(=O)C1(CC2=C(CC3=C(Oc4ccccc34)C=C(C)C2)C1)C(=O)OC', 'POTPIY'),
#  ('O=C(Nc1ccccc1c1ccccc1NC(=O)C1=CC=CO1)C1=CC=CO1', 'POWLAP'),
#  ('CC1(C)COC2(CCC3(CC2)OCC(C)(C)CO3)OC1', 'POWLIX'),
#  ('Cc1cc2Oc3ccccc3C(=O)c2c(c1)c1ccccc1', 'POZHAO'),
#  ('Cc1ccc(cc1)C(O)=O', 'PTOLIC01'),
#  ('COCOc1ccccc1C(=Cc1ccccc1)C(O)=O', 'PUBLOO'),
#  ('NC1=NC(=O)N(C=C1)C1OC(CO)C(OC=CC#N)C1O', 'PUCPAF'),
#  ('CCOC(=O)C1=NOC2(C1)N(Cc1ccccc1)C(=O)C(C)(C)C2=O', 'PUGZOH'),
#  ('CC1=CC(=NN2N=NN=C2N1)C', 'PUHHOQ'),
#  ('NC1=NN=NN1NC=O', 'PUHJIM'),
#  ('Cc1cc(C)c(c(C)c1)C1(C)CC(C1)C(=O)COc1ccccc1', 'PUJCUT'),
#  ('COC(=O)C1=C(C)NC(=C(C1c1ccc(OC)cc1)C(=O)OC)C', 'PUJPUG'),
#  ('CC1(O)C=C(C(O)c2ccc(cc2)C#N)C(=O)C(=C1)C(O)c1ccc(cc1)C#N', 'PUKZAX'),
#  ('OC(=O)C1C(C(C1c1ccncc1)C(O)=O)c1ccncc1', 'PULCAB'),
#  ('Nc1ccc(cc1N(=O)=O)C(O)=O', 'PUQFUD'),
#  ('OC(=O)c1ccc(O)c(c1)N(=O)=OO=C(O)c1ccc(N)c(OC)c1', 'PUQGAK'),
#  ('O=C1CCC2CC12N1C(C(OC1=O)c1ccccc1)c1ccccc1', 'PUTKAR'),
#  ('OC1C(OC(=O)c2ccccc2)C(=O)OC1=O', 'QACXUP'),
#  ('CC1CCC2=CC=C(O2)c2c(O)cc(O)cc2CC(=O)O1', 'QAGKOZ'),
#  ('COc1ccccc1C1C2C(=O)CCCC2(O)OC2=C1C(=O)CCC2', 'QAJNUM'),
#  ('c1ccc(nc1)N1C=NN=N1', 'QALQEA01'),
#  ('CC12CCC(O)C3(C)C1C(OC2=O)C=C1COC(=O)C=C31', 'QALRAY'),
#  ('CC12CCC(O)C(C)(OC1COC(=O)O2)C=C', 'QALTED'),
#  ('CC(=O)N1CCOCCOCCOCCN(CCOCCOCCOCC1)C(C)=O', 'QAMNIB'),
#  ('CC1CCC2N1C(=O)C(=Cc1ccccc21)c1ccccc1', 'QAQXAI'),
#  ('CC(C)C(=Cc1ccccc1)C(O)=O', 'QASTAG'),
#  ('CCc1ccc(O)c(N)c1', 'QEPFUN'),
#  ('Nc1cc2ccccc2cc1O', 'QEPGAU'),
#  ('COc1cc2C(=O)N(C)C(=O)c2cc1OC', 'QERVUF'),
#  ('COc1ccc(N)c(c1)N(=O)=O', 'QEXNIR'),
#  ('CC(C)C1C2OC(=O)C(=C2CN1C(=O)OC(C)(C)C)c1ccccc1', 'QEZYOK'),
#  ('COC1OC(CO)C(O)C1O', 'QIBTIE'),
#  ('COC1OC(CO)C(O)C1O', 'QIBTIE01'),
#  ('O=N(=O)N1CCc2ccccc12', 'QIJDAO01'),
#  ('CC(=NOC(=O)C=C)c1ccccn1', 'QIXQOE'),
#  ('O=C1Nc2ccccc2Oc2cc(cc(c12)N(=O)=O)N=[N+]=[N-]', 'QOFGIC'),
#  ('CC1=CNC2=C(C1c1ccccc1)C(=O)c1ccccc1C2=O', 'QOHRIP'),
#  ('O(c1ccccc1)c1cnccn1', 'QOLNUB'),
#  ('O=C1NC2C3CC4CC(C3)CC2(C4)C(=O)c2ccccc12', 'QOPTUL'),
#  ('CC1(C)CC(=O)C2OC32CCCCC13C#N', 'QOPWUO'),
#  ('NC1=NN=NN1NCC(N(=O)=O)(N(=O)=O)N(=O)=O', 'QORROF'),
#  ('[N-]=[N+]=NC1=NN=NN1N=C1CCC(CC1)=NN1N=NN=C1N=[N+]=[N-]', 'QOXPAV'),
#  ('CC1=CN=C2OCCN2C1=O', 'QOXVII'),
#  ('O=C1Cc2cccc(CC(=O)Cc3cccc(C1)c3)c2', 'QOYSAY'),
#  ('CCCCCCCCC', 'QQQFAY01'),
#  ('CC12OC(=O)C=C(OCc3ccccc3)C1C1C2C(=O)NC1=O', 'QUBQUZ'),
#  ('CNC(=O)c1ccc2ccccc2n1', 'QUCXMA11'),
#  ('O=C1CC2OCOCC3CC1C23', 'QUDREN'),
#  ('CC(=O)c1cccc(c1)C(O)=O', 'QUYREI'),
#  ('CCCCN1c2ccccc2c2ccc3cc(OC)ccc3c12', 'QUYXAK'),
#  ('CCOc1ccc2nc(CCCCOO)c3CCCc3c2c1', 'QUZCIY'),
#  ('CCCCCCCCCC(=O)NCCN(C)(C)[O]', 'QUZQUY'),
#  ('[N+]CCC(O)C(=O)[O-]', 'RABTUL'),
#  ('CC1=COC(C)(CC1)C(O)=O', 'RAGMUJ'),
#  ('CCCCN1C(=O)NC2(CC3(CC(=NO3)C(=O)c3ccccc3)C2)C1=O', 'RAHJAL'),
#  ('CN1C=CC=CC1=NN(=O)=O', 'RANWUY'),
#  ('OC(c1ccccc1)(c1ccccc1)C1=CN=NN1Cc1ccccc1', 'RAWXAP'),
#  ('C1c2ccc(cc2)N=C2c3ccccc3C(=Nc3ccc(Cc4ccc(cc4)N=C4c5ccccc5C(=Nc5ccc1cc5)c1ccccc41)cc3)c1ccccc21',
#   'RAYKAE'),
#  ('CCOC(=O)C1=NC=CN1C', 'REHCOX'),
#  ('C1CN2CCN=C2N1', 'REJVAE01'),
#  ('CC1NC(=O)C2CC(O)CN2C1=O', 'REQHUQ'),
#  ('COc1ccc(CCc2ccc(OC)cc2)cc1', 'RERWOA'),
#  ('Nc1ccc2OC(=O)Nc2c1', 'RESKIK'),
#  ('Cc1c(N=[N+]=[N-])nc(N=[N+]=[N-])nc1N=[N+]=[N-]', 'RETMEJ'),
#  ('CC(=O)C1CC(C#C)C1(C)C', 'REZBUU'),
#  ('CC1CC(=O)CC(C)C1C(O)=O', 'REZRUK'),
#  ('O=C1Nc2ccccc2C21OC2C(=O)c1ccccc1', 'RICYEI'),
#  ('OC(=O)Cc1ccc(CC(O)=O)cc1', 'RIGXOV'),
#  ('CC1(C)OC2C=CC(=O)C2O1', 'RIQMIO'),
#  ('N#CCCN(CCCCN(CCC#N)CCC#N)CCC#N', 'RISFAB'),
#  ('CC(Nc1ncc(cc1N(=O)=O)N(=O)=O)c1ccccc1', 'RIWQET'),
#  ('OC(CN1C=NN=N1)CN1N=CN=N1', 'RIZXEE'),
#  ('CC(C)(C)c1cc2c(N=C3C(=C4c5cc(cc(c5N=C4C(=C23)c2ccccc2)C(C)(C)C)C(C)(C)C)c2ccccc2)c(c1)C(C)(C)C',
#   'ROCLUR'),
#  ('CN1N=C(C(=C1N(=O)=O)C)N(=O)=O', 'RODLOM'),
#  ('CC(C)(C)OC(=O)N1CC2CC1C(=O)O2', 'ROGGEA'),
#  ('Nc1[n+]cccc1C(=O)[O-]', 'ROGXIU01'),
#  ('COC(=O)c1ccc(cc1)N(=O)=O', 'RUGNIR'),
#  ('Cc1ccc(cc1)N1C=C(C(=O)c2ccc(C)cc2)C(=N1)C1=CC=C(O1)N(=O)=O', 'RUGPAL'),
#  ('CC1(C)CC(O)CC(C)(C)N1N=O', 'RUPFEO'),
#  ('c1cc(ccn1)c1nnc(nn1)c1ccncc1', 'RUYKIF01'),
#  ('O=N(=O)c1cccc(Oc2cnc3ccccc3n2)c1', 'SABDEG'),
#  ('CC(C)C1=NC(=CC(=O)N1)C', 'SABKIR'),
#  ('N#Cc1ccc(OCC2=CC=CO2)cc1C#N', 'SAGQOI'),
#  ('COc1ccc(cc1OC)C=C1C(=O)N(C)C(=O)N(C)C1=O', 'SAGVED'),
#  ('O=C1OCCC1(C(=O)c1ccc2ccccc2c1)c1ccccc1', 'SAHPIC'),
#  ('ON=C1CCCCCCCCCCC1=O', 'SAHPUO'),
#  ('O=C1NCCC2=CN=CN12', 'SAJHIV'),
#  ('OC(=O)c1ccccc1O', 'SALIAC16'),
#  ('CC(C)(C)c1ccccc1N1C2C=CC2C1=O', 'SAPVUC'),
#  ('CN(c1ccccc1N(=O)=O)N(=O)=O', 'SATBUL'),
#  ('CN(c1cccc(c1)N(=O)=O)N(=O)=O', 'SATCAS'),
#  ('CC(=O)c1cc2CCCc3cccc(c1O)c23', 'SAVZEV'),
#  ('ON=CC1=NNC=C1', 'SAWJUW'),
#  ('C1CCC2(CC1)OOC1(CCCCC1)OO2', 'SCHOCH11'),
#  ('NC(N)=C(N(=O)=O)N(=O)=O', 'SEDTUQ09'),
#  ('CC1NC(=O)C2CCCC2=C1', 'SEMGOH'),
#  ('O=C1Oc2cc(C=Cc3ccccc3)ccc2C=C1', 'SEPSUC'),
#  ('COC(=O)CNC(=O)C(=C)NC(=O)CNC(=O)OC(C)(C)C', 'SETQAK'),
#  ('O=C1C2CCN(CC2)C1=CC1=CN(Cc2ccccc2)c2ccc(cc12)N(=O)=O', 'SETWEU'),
#  ('CC1=CC(O)C2OC2C1=O', 'SEWHUY'),
#  ('CC12OC1C(=O)c1ccccc1C2=O', 'SIGYEN'),
#  ('O=C(CCC(=O)Nc1ccc(cc1)N(=O)=O)Nc1ccccc1', 'SIMSAJ'),
#  ('CC(=O)Oc1ccc2c(Oc3cc(OC(C)=O)ccc3C32OC(=O)c2ccccc32)c1', 'SIQJIL'),
#  ('CCOC(=O)C1(NC(=O)C2CN(Cc3ccccc3)OC12)C#N', 'SOCBOC'),
#  ('COC1CC(N(C1)C(C)=O)C(=O)OC', 'SODJEB'),
#  ('CC(C)c1cccc(C(C)C)c1N=Cc1cc(ccn1[O])N(=O)=O', 'SOHXOD'),
#  ('CC(=O)NC1COC2COC(OC2C1OC(C)=O)c1ccccc1', 'SOJXUL'),
#  ('OC(=O)C1CC(=O)C1', 'SOLTET'),
#  ('CC(C)=CC(O)CC(C)=CCOc1c2C=COc2cc2OC(=O)C=Cc12', 'SOLXUN'),
#  ('CNc1cc(cc(C)[n+]1[O-])N(=O)=O', 'SOVNUN'),
#  ('O=C1NCCc2ccccc12', 'SOWQOL'),
#  ('COc1ccc(cc1)C=Cc1ccccc1NC(C)=O', 'SOYMUP'),
#  ('OCC1OC(OC2(CO)OC(CO)C(O)C2O)C(O)C(O)C1O', 'SUCROS14'),
#  ('Cc1cc(C)c(CCc2c(C)cc(C)cc2C)c(C)c1', 'SUCSOY02'),
#  ('CC1(C)C(=O)N(c2ccccc2)C(=N)C1(C)N=Nc1ccc(cc1)N(=O)=O', 'SUQDEO'),
#  ('CC1OC2CC3OCCCC3OC2CC1O', 'SUQQEB'),
#  ('O=C1CC2(CCCC2C=C1)C#N', 'SUVBIV'),
#  ('O=C1OCCC#CCCOC(=O)c2ccccc12', 'SUVSAE'),
#  ('O=C1NC(Cc2ccccc2)C2=CN=NN2c2ccccc12', 'SUWPAC01'),
#  ('CCOC(=O)C1=C(N(N=C1)C(C)(C)C)c1ccccc1', 'SUYTOW'),
#  ('CC(=O)N1C(=O)C(c2ccccc12)=C(c1ccccc1)C(=O)c1cccnc1', 'SUYVIS'),
#  ('CCOc1ccc(C=CC(=O)c2ccccc2O)cc1', 'SUZPIN'),
#  ('N#Cc1ccc2ccccc2n1', 'SUZXOB'),
#  ('COc1cc(OC)c(C=NN=Cc2c(OC)cc(OC)cc2OC)c(OC)c1', 'SUZYIW'),
#  ('c1ccc(nc1)c1ccc(cn1)N=Nc1ccc(nc1)c1ccccn1', 'TADHEM'),
#  ('CC1(C)OC(C)(CCC1C(O)=O)C(O)=O', 'TADNUI'),
#  ('CCOC(=O)C=C1CC(OC(O1)c1ccncc1)c1ccncc1', 'TALDAM'),
#  ('OC(=O)c1ccc(Oc2ccc(cc2)C(O)=O)cc1', 'TAPSAF01'),
#  ('O=C(C1=Cc2ccccc2O1)c1ccccc1', 'TAPZUG'),
#  ('O=C1OC(CC(=C1)C=Cc1ccccc1)c1ccccc1', 'TAVDOK'),
#  ('OCC1OC(C(O)C1O)c1ccccc1', 'TAWMUZ01'),
#  ('COc1ccc2ccccc2c1C=NN=Cc1c(OC)ccc2ccccc12', 'TAZXOI'),
#  ('c1ccc2c(c1)cccc2C=NN=Cc1cccc2ccccc12', 'TAZXUO'),
#  ('N#CC1(OC1(C#N)C#N)C#N', 'TCYNEO04'),
#  ('CNC(=O)C(Cc1ccccc1)N=C1OC(=O)C(=C1CC(C)C)C', 'TEGPUR'),
#  ('O=C1C2CCN(CC2)C1=CC1CCCCC1', 'TERREO'),
#  ('CC1(C)C2CCC3(C)C(C(=O)C=C4C5CC(C)(CCC5(C)CCC34C)C(O)=O)C2(C)CCC1=O',
#   'TEVYAV'),
#  ('COC(=O)C=C(N1C=NC(=C1)N(=O)=O)C(=O)OC', 'TIBHES'),
#  ('OC(=O)C1=Cc2ccccc2OC1=O', 'TICHUI04'),
#  ('COC1OCC(O)C(O)C1O', 'TICXUY01'),
#  ('CCOC(=O)C1OCN(C1c1ccccc1)c1ccc(OC)cc1', 'TIFGAR'),
#  ('CC(=O)c1ccc(cc1)C(O)=O', 'TIHLIG'),
#  ('C1CC21CC2=C1CC21CC2', 'TIHWIQ'),
#  ('O=N(=O)C1=CC2=NOC(=C2C=C1)c1ccccn1', 'TIJPAE'),
#  ('CC(C)(C)NC(=O)C=CC(=Cc1ccc(cc1)C#N)c1ccc(cc1)C#N', 'TIYJER'),
#  ('O=C1c2ccccc2C(=O)C21C(c1ccc3ccccc3c1)C1(C2c2ccc3ccccc3c2)C(=O)c2ccccc2C1=O',
#   'TOLNAK'),
#  ('CC1=Cc2c3C4C5CCC(C5)C4C(=O)c3c3ccccc3c2C(=O)O1', 'TOPCAD'),
#  ('c1ccc(cc1)C(c1ccccc1)=C(c1ccccc1)c1ccccc1', 'TPHETY02'),
#  ('N1C2=C(c3ccccc3)C3=NC(=C(C4=CC=C(N4)C(=C4C=CC(=N4)C(=C1C=C2)c1ccccc1)c1ccccc1)c1ccccc1)C=C3',
#   'TPHPOR11'),
#  ('CC(C)C12OC1C1OC31C1(C)CCC4=C(COC4=O)C1CC1OC31C2O', 'TRIPOL11'),
#  ('O=C(NN=C(c1ccccc1)C(=NNC(=O)c1ccccc1)c1ccccc1)c1ccccc1', 'TUMDIP01'),
#  ('Cc1ccc(cc1)[N+]1=NOC(=C1C=O)[O-]', 'TUNWIJ'),
#  ('COC(=O)C1=C(C)NC(=C(C1c1ccc(OC)c(OC)c1)C(=O)OC)C', 'TUPGUH'),
#  ('CCC1=C(C)C(=O)NN1', 'TUPHAO'),
#  ('CCC1NC(=O)C(O)(COCc2ccccc2)C1c1ccccc1', 'UBUXIA'),
#  ('CC(=O)N(CC(=O)N1CCCCC1)c1ccccc1', 'UCUBIF'),
#  ('CC(=C)C1CCC23OC2C(CC2(C)CC(=O)C(CC(=O)C1)O2)OC3=O', 'UDAKUH'),
#  ('CO[N+]1=NOC(=O)[C-]1C(=O)OC', 'UDOZOD'),
#  ('COC1=NC(=CN1C)N(=O)=O', 'UDUQUG'),
#  ('CCCC1OC(=O)CCCC=CC2OC(C)(C)OC12', 'UFOSOX'),
#  ('COC1CCCC21COC(=O)N2', 'UGECAK'),
#  ('N#CC(NCCCNC(C#N)c1ccccc1)c1ccccc1', 'UGIVOW'),
#  ('N#CC(NCCCCNC(C#N)c1ccccc1)c1ccccc1', 'UGIVUC'),
#  ('CC1(C)OC2CC3(C)OC(=O)OCC3OC2(C)CC1O', 'UHULUE'),
#  ('O=N(=O)c1ccccc1N=[N+]=[N-]', 'UJEREG01'),
#  ('CCC1C(CN(=O)=O)c2ccccc2OC1=O', 'UKEPIK'),
#  ('CCCCCCCCCN1C(=O)Nc2cc(ccc12)N(=O)=O', 'ULEZAN'),
#  ('Cc1cc(C)cc(c1)N=C(C)C(C)=Nc1cc(C)cc(C)c1', 'UMATUY'),
#  ('O=C(NCc1ccccc1)c1ccc(cc1)C(=O)NCc1ccccc1', 'UMOPAO'),
#  ('CC1=Nc2ccccc2C(=O)N1O', 'UMOTUM'),
#  ('CCCOc1cccc2c(OCCC)cccc12', 'UNAMAY'),
#  ('CCCCCOc1cccc2c(OCCCCC)cccc12', 'UNAMIG'),
#  ('CCCCCCCCOc1cccc2c(OCCCCCCCC)cccc12', 'UNAMOM'),
#  ('CCCCN1C(=O)c2ccc3C(=O)N(CCCC)C(=O)c4ccc(C1=O)c2c34', 'UNANAZ'),
#  ('CC1CCCC2CC(=O)C3(OC3(C)C)C(OC(C)=O)C12C', 'UNEGUQ'),
#  ('CC(=O)OCC1OC(Oc2ccc(C=O)cc2)C(OC(C)=O)C(OC(C)=O)C1OC(C)=O', 'UNUKIY'),
#  ('Oc1cccc2CCC(=O)c12', 'UPACUK'),
#  ('CC(O)CCc1ccc(O)cc1', 'UPAHUP'),
#  ('C1=CN(N=C1)c1cc(cc(n1)N1C=CC=N1)c1cc(nc(c1)N1C=CC=N1)N1C=CC=N1', 'UPEHED'),
#  ('C1=CN(N=N1)N=NN1C=CN=N1', 'UPIDED'),
#  ('CC(=NNc1ccccc1)C(O)=O', 'URECOK'),
#  ('CCCC1OOC2(CCCCC2)OO1', 'USAHUS'),
#  ('COC(=O)C1(CC(C)C)N=C(C)OC21C(=O)N(C)C(=O)c1ccccc21', 'USOGEP'),
#  ('CCOC(=O)C1(CC(=O)C2C3CC(C=C3)C12)CN(=O)=O', 'USOKIX'),
#  ('O=C(ON=Cc1cc2OCOc2cc1c1ccccc1)Oc1ccccc1', 'UVIPEV'),
#  ('OC1(c2ccccc2)C(=O)C(c2ccccc2)(c2ccccc2)c2ccccc12', 'UVONID'),
#  ('COc1ccc(cc1)N1C(=O)c2ccc3ccccc3c2c2c1ccc1ccccc21', 'UWEQOD'),
#  ('CCC(=O)NN(=O)=O', 'UXIJIV'),
#  ('CC(CN1C(=O)c2ccccc2C1=O)(C=C)C(O)c1ccc(cc1)N(=O)=O', 'UXOQUU'),
#  ('CN1C=C(N=C1C1OCCO1)N(=O)=O', 'UXUGAW'),
#  ('CCOC(=O)C=CC(CC(C)C)NC(=O)C=CC(CC(C)C)NC(=O)OC(C)(C)C', 'UYIHAM'),
#  ('CC1(O)C(CN2CCCC2)C=C(CCc2ccccc2)C1=O', 'UZEVAX'),
#  ('COC1(C)OC2CC(=O)C(=CC2OC1(C)OC)CO', 'VADPUN'),
#  ('CC(C)(C)c1ccc(cc1)C1=C2C(=O)NC(=C2C(=O)N1)c1ccccc1', 'VAGPEZ'),
#  ('Oc1ccc(cc1)C1=NC1c1ccccc1', 'VAGVEG'),
#  ('O=C1OC(=O)c2ccccc2c2ccccc12', 'VAHVUX'),
#  ('[N+]C(C(C)C)C(=O)[O-]', 'VALIDL03'),
#  ('CC1CC2C3CC=C4CC(O)CCC4(C)C3CCC2(C)C1C(C)=O', 'VARWUG01'),
#  ('O=C1NC(=C2C(=O)NC(=C12)c1cccnc1)c1cccnc1', 'VAZPAO'),
#  ('Oc1ccc([O-])c(C=[N+]c2ccccc2N=Cc2cc(O)ccc2O)c1', 'VEFTEG'),
#  ('C=NNc1ccc(cc1N(=O)=O)N(=O)=O', 'VETLIQ'),
#  ('[N+]C(CC(N)=O)C(=O)[O-]', 'VIKKEG'),
#  ('OC12CCOC1CC(=O)C1OC21', 'VISDIL'),
#  ('O=N(=O)N=C1NN=NN1', 'VIWRAV'),
#  ('CCOC(N)=NC#N', 'VODJEE'),
#  ('NNC(=O)NN1N=NN=C1N', 'VODWER'),
#  ('CC(C)CC1N(CC2CC12O)Cc1ccccc1', 'VOFSIT'),
#  ('CCC(C)C1N(CC2CC12O)Cc1ccccc1', 'VOFSOZ'),
#  ('CCOC(=O)C=C(N1C(=O)c2ccccc2C1=O)c1ccccc1', 'VOHJOS'),
#  ('CCOC(=O)C=C(C)N1C(=O)c2ccccc2C1=O', 'VOHJUY'),
#  ('COc1ccc(cc1)C=CN(=O)=O', 'VOPXAZ02'),
#  ('COC1CCCC2C1C(OC(=O)c1ccccc1)C(=C1C3(O)CC4CC5C3CCC(C)N5C214)C(=O)OC',
#   'VUGVAV'),
#  ('CC1N(C(=O)c2cccc3ccccc23)C(C)(C)OC1=O', 'VUMXEH'),
#  ('NN1C=NN=C1N', 'VUPTAC02'),
#  ('OC1C2CC3C1N(C(=O)C3C2C(O)=O)c1cccc(c1)N(=O)=O', 'VUSWAI'),
#  ('OCCCCCCCCCCN1C=CN=C1', 'VUVREK'),
#  ('C1CNC(NC1)(c1ccccc1)c1ccccn1', 'WACYUW'),
#  ('COc1ccc(cc1)[N+]1=NOC(=C1)[O-]', 'WADNOG'),
#  ('COc1ccc(c(C=O)c1)c1ccc(OC)c(OC)c1OC', 'WAFXIL'),
#  ('CCOC(=O)C(=O)NC1CCC(CC1)NC(=O)C(=O)OCC', 'WAVYOI'),
#  ('N#Cc1ccc(C=Cc2ccc(cc2)C#N)cc1', 'WEFBIT'),
#  ('Cc1ccc(cc1)C(N)=CC=CC=C(N)c1ccc(C)cc1', 'WELZAO'),
#  ('OCCCCCCCCCCO', 'WESTIX'),
#  ('Oc1ccc(cc1)C1(CCCCC1)c1ccc(O)cc1', 'WETFAD01'),
#  ('NC(=[N+])C(=O)[O-]', 'WETGAE'),
#  ('CCN(CC)C(=O)c1cccc(n1)C1=NN(Cc2ccc(CN3C=CC(=N3)c3cccc(n3)C(=O)N(CC)CC)cc2)C=C1',
#   'WEZJIV'),
#  ('COc1ccc(cc1)C(C)N1C(CCC1C#C)C#C', 'WIDSOS'),
#  ('CC1=CC(=O)Oc2cc(N)ccc12', 'WIKDEZ01'),
#  ('O=C1C2CCCC1CCC2', 'WIQCUU'),
#  ('CC(=O)C1=C(O)c2ccccc2OC1=O', 'WOKPER02'),
#  ('CCOC1=NC(=CC2=C(C)C(=C(C)N2)CC)C(=C1C)CC', 'WOKPES'),
#  ('CC1CC(OC1=O)C1CCC2N1C(=O)CCC12CC(C)C(=O)O1', 'WONJUF'),
#  ('OC12CCCC(CC(=N1)c1ccccc1)C2', 'WULTED'),
#  ('C1C2CC3C4CC5C6CC7C8CC9CC7C(C2)(C6C14)C3(C9)C58', 'WULYEI'),
#  ('Nc1ncnc2N(CC#C)C=Nc12', 'WUSGOH'),
#  ('C(N1C=CN=C1)c1c2ccccc2c(CN2C=CN=C2)c2ccccc12', 'WUTGUO'),
#  ('O=C1OCC(CC2CC12N(=O)=O)N1C(=O)c2ccccc2C1=O', 'WUWHIG'),
#  ('O=N(=O)c1ccc([O-])c(C=[N+]C2CCCCC2)c1', 'XABCUZ'),
#  ('O=C1C2CCCCC(C2)C(=O)N1c1ccc2OCOc2c1', 'XACNIA'),
#  ('O=N(=O)c1ccc(cc1)C(=Cc1ccccc1)C#N', 'XACQEZ'),
#  ('CON1N=NNC1=NN(=O)=O', 'XAJHEX'),
#  ('COc1ccc2OC3(CCc2c1)CCc1cccc(OC)c1O3', 'XALYOZ'),
#  ('O1C2C1C1C3C4OC4C2C2OC2C13', 'XAMZIV'),
#  ('Cc1ccnc(c1)c1cc(ccn1)C(=O)NCCNC(=O)OC(C)(C)C', 'XAPLOQ'),
#  ('NC(=O)CN=[N+]=[N-]', 'XAVZUP'),
#  ('CN(C)c1cccc2c([N+]=Cc3cc(ccc3[O-])N(=O)=O)ccc(N(C)C)c12', 'XEBRIG'),
#  ('COC(=O)c1cc(nc(C=Cc2ccc(C)cc2)c1C(=O)OC)N(C)C', 'XEJBIY'),
#  ('CC(C)=C(OC(=O)c1ccc(cc1)N(=O)=O)C#CC(OC(=O)c1ccc(cc1)N(=O)=O)=C(C)C',
#   'XEKMAC'),
#  ('COc1cc(cc(OC)c1OC)C#Cc1c2ccccc2c(C#Cc2cc(OC)c(OC)c(OC)c2)c2ccccc12',
#   'XEPYAT'),
#  ('Cc1nncc(n1)c1cnnc(C)n1', 'XICVOV'),
#  ('CC12CCC3C(CC(=O)C4CC(=O)CC=C3C4)C1CCC2=O', 'XIGHUR'),
#  ('COc1cc(C=O)cc(O)c1O', 'XIGWAM'),
#  ('OC1CCC(CC1)(c1ccc(O)cc1)c1ccc(O)cc1', 'XIJFEB'),
#  ('Cc1cc(C)c(C#N)c(OCCN2C(=O)c3ccccc3C2=O)n1', 'XIMSUI'),
#  ('O=C(NN(=O)=O)NN(=O)=O', 'XIXQOL'),
#  ('O=C(Oc1ccccc1C=NN=Cc1ccccc1OC(=O)c1ccccc1)c1ccccc1', 'XIYYIO'),
#  ('COC1(O)C(OC(C)=O)C(COC21COC(C)(C)O2)OC(C)=O', 'XOCFEB'),
#  ('COC(=O)C(=Cc1ccc(cc1)N(=O)=O)C(=O)OC', 'XOCYOE'),
#  ('CC1C(OC(C)=O)C(c2ccccc2)C1(O)c1ccccc1', 'XOHGAD'),
#  ('COC(=O)C(O)(C1OC(=O)C=C1)c1ccccc1', 'XOHHEI'),
#  ('COC(=O)C1=Cc2ccc(CCCCN(C(=O)OC(C)(C)C)C(=Cc3ccc(CCCCN1C(=O)OC(C)(C)C)cc3)C(=O)OC)cc2',
#   'XONMES'),
#  ('OC1COC(OCCCCCCCCCCCCOC2OCC(O)C=C2)C=C1', 'XONVAY'),
#  ('CC(C)=NN1N=NN=C1N', 'XOYWEO'),
#  ('O=N(=O)C=CC1=CC=CO1', 'XOZBUK'),
#  ('C=CC1=NOC(C1)C1=NOC(=C1)N(=O)=O', 'XUHREX'),
#  ('COC(=O)c1cc(C)nc2N(C=C(C#N)c12)C(C)(C)C', 'XUKJIX'),
#  ('C(CN1N=CN=N1)N1N=CN=N1', 'XUQLUQ'),
#  ('Cc1ccccc1C=NN1C=NN=C1', 'XURZUF'),
#  ('COC1OCC(O)C(O)C1O', 'XYLOBM02'),
#  ('C#CCOc1ccc(cc1)C=NN=Cc1ccc(OCC#C)cc1', 'YAGJEX'),
#  ('COC(=O)Nc1ccccc1NC(=O)OC', 'YAGLAU'),
#  ('Cc1cc(nc(NCc2ccccc2)n1)c1ccccc1', 'YAGPON'),
#  ('CCCCNc1nc(cc(n1)c1ccccc1)c1ccccc1', 'YAGSUW'),
#  ('COc1ccc(C)c2C(=O)c3ccccc3C(=O)c12', 'YAGWEK'),
#  ('CCN1C(=Nc2ccccc12)C=CC1=Nc2ccccc2N1CC', 'YASRIU01'),
#  ('OC1N2C=CN=C2C(O)N2C=CN=C12', 'YASSAN'),
#  ('COc1ccc(CNC(=O)C(=O)C2=CNc3ccccc23)cc1', 'YEFXUD'),
#  ('COC(=O)C(C1CCCC(=O)C1)C(=O)OC', 'YEGVUC'),
#  ('CCOC(=O)c1ccc(NC(=O)c2ccc3cc(ccc3c2)C(=O)Nc2ccc(cc2)C(=O)OCC)cc1',
#   'YETRIZ'),
#  ('CCOC(=O)c1ccc(NC(=O)c2ccc(cc2)C(=O)Nc2ccc(cc2)C(=O)OCC)cc1', 'YETROF'),
#  ('OCC1OC(O)C(O)CC1O', 'YIGGIF'),
#  ('O=C1C(Oc2ccccc12)c1ccccc1', 'YIHFOL'),
#  ('CC(O)C(O)=O', 'YILLAG'),
#  ('CCCCC12OC(=O)CC31C(N(C)c1ccccc31)C(=C2)C', 'YINKOW'),
#  ('c1ccc(cc1)C1=Nc2ccc(cc2N=C1c1ccccc1)c1ccc2N=C(c3ccccc3)C(=Nc2c1)c1ccccc1',
#   'YIRMAO'),
#  ('COc1ccc(cc1)C(=Cc1cc(OC)c(cc1OC)C=C(C#N)c1ccc(OC)cc1)C#N', 'YIVQEA'),
#  ('CCCNc1ccc(cc1N(=O)=O)C(=O)OCC', 'YODFUT'),
#  ('Oc1ccc(c2C(=O)C=CC(=O)c12)N(=O)=O', 'YODKAE'),
#  ('CC(C)=NN1N=NN=C1N=[N+]=[N-]', 'YOHHIN'),
#  ('CC1C2OCC(N2C1=O)c1ccccc1', 'YOMKER01'),
#  ('CC(=O)OC(COC(=O)c1ccccc1)C1OC(=O)C=CC1OC(C)=O', 'YONWII'),
#  ('c1cnc2nc(cnc2c1)c1cnc2cccnc2n1', 'YOPSIG'),
#  ('CN(C)c1ccc(c(c1)C(=O)N(C)C)N(=O)=O', 'YOTSUW'),
#  ('CCOC(=O)C1=C(C(C#N)C(N)=O)c2ccccc2N(CC)C1=O', 'YOWHAU'),
#  ('COC(=O)C1=COC=CN1C(=O)OC(C)(C)C', 'YOXBAP'),
#  ('CC(C)C12CCC(C)(O1)C1CCC(C)(O)C31OC23', 'YUGGIR'),
#  ('CN1C(=O)N(C)c2nc3cccc(C)c3nc2C1=O', 'YUKPUQ'),
#  ('O=C1NC(=NO1)C1=NOC(=O)N1', 'YUMPIG'),
#  ('CC1(C)OCC(O1)C1CC(=C)CCC21CCCCN=CC1(CCCCN=C2)CCC(=C)CC1C1COC(C)(C)O1',
#   'YUPZAL'),
#  ('CN(C)c1ccc(cc1)C=NC1=C(C)C(=NO1)C', 'YUPZUF'),
#  ('CCOC(=O)C(C)=C(CC(O)c1ccc(cc1)C#N)c1ccccc1', 'YURRIN'),
#  ('CC1=C(C=C(C#N)C(=O)N1)c1ccncc1C', 'ZILFUV'),
#  ('Cc1cc(C=O)c(O)c(c1)C(C)(C)C', 'ZOJRAR01'),
#  ('OCC1OC(CC1O)N1C=NC2=C1C(=O)NC=N2', 'ZOZXOB'),
#  ('COc1ccc(cc1)C1C(C(C1C(O)=O)c1ccc(OC)cc1)C(O)=O', 'ZZZDWY01')]

# %% [markdown]
# Functional Group Data Variables Defined
#
# - <b>all_data</b> each entry is a molecule's derived functional group data using the all data format
# - <b>exact_data</b> each entry is a molecule's derived functional group data using the exact data format
# - <b>mol</b> a variable for an individual molecule based on the <b>chem.molecule</b> Molecule class
# - <b>failed_mols</b> a list of molecules by structure name which did not pass the functional group algorithm due to an internal error
#
# <b>all_data</b> and <b>exact_data</b> contain the list version of data which is converted into a table format with column names and row values via <b>pandas</b> later. See below for their usages.

# %%
all_data: list[dict] = []
exact_data: list[dict] = []
mol: Molecule
failed_mols: list[str] = []

# %% [markdown]
# Logging File Set-Up
#
# The logging setup code below create an empty main.log file and prepares the <b>logging</b> module to log failed structure information into the main.log file during the script structures processing steps below

# %%
with open("main.log", mode="w", encoding="UTF-8") as file:
    file.truncate(0)
logging.basicConfig(format='%(message)s', filename='main.log')

# %% [markdown]
# ## Script Structures Processing

# %% [markdown]
# Functional Groups Identification Structures Processing
#
# The code loop below processes through the loaded SMILES codes and identifies their functional groups using the <b>Molecule</b> class from the IFG python package. The data extracted from each code is appended to each <b>all_data</b> and <b>exact_data</b> data list accordingly until all structures have been processed.

# %%
##### Structure Bar Status #####
with tqdm(total=len(STRUCTURES)) as bar:

    ##### SMILES Structure Loop #####
    for (smiles, refcode) in STRUCTURES:

        ##### Molecule Data #####
        try:
            mol = Molecule(smiles, name=refcode, type="mol")
        except:
            failed_mols.append(smiles + " " + refcode)
            logging.error(f"{refcode} {smiles} Failed to be processed \n {traceback.format_exc()}")
            bar.update(1)
            continue

        ##### All Functional Group Format Data #####
        all_data.append({
            "Refcode": mol.name,
            "SMILES": smiles,
            "Aromatic Rings": mol.aromatic_ring_count,
            "Non Aromatic Rings": mol.non_aromatic_ring_count,
            "Rings": mol.total_ring_count,
            "AminoAcid": "Yes" if mol.amino_acid else "No",
            **mol.functional_groups_all,
        })

        ##### Exact Functional Group Format Data #####
        exact_data.append({
            "Refcode": mol.name,
            "SMILES": smiles,
            "Aromatic Rings": mol.aromatic_ring_count,
            "Non Aromatic Rings": mol.non_aromatic_ring_count,
            "Rings": mol.total_ring_count,
            "AminoAcid": "Yes" if mol.amino_acid else "No",
            **mol.functional_groups_exact,
        })

        ##### Status Bar Update #####
        bar.update(1)
# Out:
# 100%|██████████| 831/831 [00:05<00:00, 148.04it/s]

# %% [markdown]
# Failed Structures Output
#
# For a brief inspection of the failed stuctures, use the code cell below. For greater detail, check out the main.log file in your `ifg/scripts` folder

# %%
failed_mols
# Out:
# []

# %% [markdown]
# ## Script Data Tabulation

# %% [markdown]
# Functional Group Dataframes Set-Up
#
# The following two <b>pandas</b> dataframes <b>df_all</b> and <b>df_exact</b> are python tables which convert the <b>all_data</b> and <b>exact_data</b> data lists collected from the script processing into tabulated row/column data that can be exported into excel, respectively.

# %%
df_all = pandas.DataFrame(all_data).fillna(0).set_index("Refcode")
df_exact = pandas.DataFrame(exact_data).fillna(0).set_index("Refcode")

# %% [markdown]
# Show the tabulated version of <b>all_data</b> (<b>df_all</b>)

# %%
df_all
# Out:
#                                                   SMILES  Aromatic Rings  \
# Refcode
# ABAWEG01                                CC(=O)NCCNC(C)=O               0
# ABEJIC      c1ccc2c(c1)cccc2C#Cc1ccccc1C#Cc1cccc2ccccc12               5
# ABEJOH           O=C1NC2C(N(CN2N(=O)=O)N(=O)=O)N1N(=O)=O               0
# ABEWAG                                               COC               0
# ACETAC07                                         CC(O)=O               0
# ...                                                  ...             ...
# YURRIN        CCOC(=O)C(C)=C(CC(O)c1ccc(cc1)C#N)c1ccccc1               2
# ZILFUV                   CC1=C(C=C(C#N)C(=O)N1)c1ccncc1C               1
# ZOJRAR01                     Cc1cc(C=O)c(O)c(c1)C(C)(C)C               1
# ZOZXOB                  OCC1OC(CC1O)N1C=NC2=C1C(=O)NC=N2               0
# ZZZDWY01  COc1ccc(cc1)C1C(C(C1C(O)=O)c1ccc(OC)cc1)C(O)=O               2
#
#           Non Aromatic Rings  Rings AminoAcid  Ketone  Amide  SecondaryAmine  \
# Refcode
# ABAWEG01                   0      0        No     2.0    2.0             2.0
# ABEJIC                     0      5        No     0.0    0.0             0.0
# ABEJOH                     2      2        No     0.0    0.0             0.0
# ABEWAG                     0      0        No     0.0    0.0             0.0
# ACETAC07                   0      0        No     1.0    0.0             0.0
# ...                      ...    ...       ...     ...    ...             ...
# YURRIN                     0      2        No     1.0    0.0             0.0
# ZILFUV                     1      2        No     0.0    0.0             0.0
# ZOJRAR01                   0      1        No     0.0    0.0             0.0
# ZOZXOB                     3      3        No     0.0    0.0             0.0
# ZZZDWY01                   1      3        No     2.0    0.0             0.0
#
#           Alkyne  Non Aromatic Ketone  ...  Imide  HydroPeroxide  \
# Refcode                                ...
# ABAWEG01     0.0                  0.0  ...    0.0            0.0
# ABEJIC       2.0                  0.0  ...    0.0            0.0
# ABEJOH       0.0                  1.0  ...    0.0            0.0
# ABEWAG       0.0                  0.0  ...    0.0            0.0
# ACETAC07     0.0                  0.0  ...    0.0            0.0
# ...          ...                  ...  ...    ...            ...
# YURRIN       0.0                  0.0  ...    0.0            0.0
# ZILFUV       0.0                  1.0  ...    0.0            0.0
# ZOJRAR01     0.0                  0.0  ...    0.0            0.0
# ZOZXOB       0.0                  1.0  ...    0.0            0.0
# ZZZDWY01     0.0                  0.0  ...    0.0            0.0
#
#           Non Aromatic Carbonate  Non Aromatic Alkyne  Isonitrile  \
# Refcode
# ABAWEG01                     0.0                  0.0         0.0
# ABEJIC                       0.0                  0.0         0.0
# ABEJOH                       0.0                  0.0         0.0
# ABEWAG                       0.0                  0.0         0.0
# ACETAC07                     0.0                  0.0         0.0
# ...                          ...                  ...         ...
# YURRIN                       0.0                  0.0         0.0
# ZILFUV                       0.0                  0.0         0.0
# ZOJRAR01                     0.0                  0.0         0.0
# ZOZXOB                       0.0                  0.0         0.0
# ZZZDWY01                     0.0                  0.0         0.0
#
#           Aromatic TertiaryAmine  Aldoxime  Non Aromatic Peroxide  Carbonate  \
# Refcode
# ABAWEG01                     0.0       0.0                    0.0        0.0
# ABEJIC                       0.0       0.0                    0.0        0.0
# ABEJOH                       0.0       0.0                    0.0        0.0
# ABEWAG                       0.0       0.0                    0.0        0.0
# ACETAC07                     0.0       0.0                    0.0        0.0
# ...                          ...       ...                    ...        ...
# YURRIN                       0.0       0.0                    0.0        0.0
# ZILFUV                       0.0       0.0                    0.0        0.0
# ZOJRAR01                     0.0       0.0                    0.0        0.0
# ZOZXOB                       0.0       0.0                    0.0        0.0
# ZZZDWY01                     0.0       0.0                    0.0        0.0
#
#           Acetal
# Refcode
# ABAWEG01     0.0
# ABEJIC       0.0
# ABEJOH       0.0
# ABEWAG       0.0
# ACETAC07     0.0
# ...          ...
# YURRIN       0.0
# ZILFUV       0.0
# ZOJRAR01     0.0
# ZOZXOB       0.0
# ZZZDWY01     0.0
#
# [831 rows x 57 columns]

# %% [markdown]
# Show the tabulated version of <b>exact_data</b> (<b>df_exact</b>)

# %%
df_exact
# Out:
#                                                   SMILES  Aromatic Rings  \
# Refcode
# ABAWEG01                                CC(=O)NCCNC(C)=O               0
# ABEJIC      c1ccc2c(c1)cccc2C#Cc1ccccc1C#Cc1cccc2ccccc12               5
# ABEJOH           O=C1NC2C(N(CN2N(=O)=O)N(=O)=O)N1N(=O)=O               0
# ABEWAG                                               COC               0
# ACETAC07                                         CC(O)=O               0
# ...                                                  ...             ...
# YURRIN        CCOC(=O)C(C)=C(CC(O)c1ccc(cc1)C#N)c1ccccc1               2
# ZILFUV                   CC1=C(C=C(C#N)C(=O)N1)c1ccncc1C               1
# ZOJRAR01                     Cc1cc(C=O)c(O)c(c1)C(C)(C)C               1
# ZOZXOB                  OCC1OC(CC1O)N1C=NC2=C1C(=O)NC=N2               0
# ZZZDWY01  COc1ccc(cc1)C1C(C(C1C(O)=O)c1ccc(OC)cc1)C(O)=O               2
#
#           Non Aromatic Rings  Rings AminoAcid  Amide  Alkyne  \
# Refcode
# ABAWEG01                   0      0        No    2.0     0.0
# ABEJIC                     0      5        No    0.0     2.0
# ABEJOH                     2      2        No    0.0     0.0
# ABEWAG                     0      0        No    0.0     0.0
# ACETAC07                   0      0        No    0.0     0.0
# ...                      ...    ...       ...    ...     ...
# YURRIN                     0      2        No    0.0     0.0
# ZILFUV                     1      2        No    0.0     0.0
# ZOJRAR01                   0      1        No    0.0     0.0
# ZOZXOB                     3      3        No    0.0     0.0
# ZZZDWY01                   1      3        No    0.0     0.0
#
#           Non Aromatic Amide  Non Aromatic TertiaryAmine  Nitro  ...  Imide  \
# Refcode                                                          ...
# ABAWEG01                 0.0                         0.0    0.0  ...    0.0
# ABEJIC                   0.0                         0.0    0.0  ...    0.0
# ABEJOH                   2.0                         2.0    3.0  ...    0.0
# ABEWAG                   0.0                         0.0    0.0  ...    0.0
# ACETAC07                 0.0                         0.0    0.0  ...    0.0
# ...                      ...                         ...    ...  ...    ...
# YURRIN                   0.0                         0.0    0.0  ...    0.0
# ZILFUV                   1.0                         0.0    0.0  ...    0.0
# ZOJRAR01                 0.0                         0.0    0.0  ...    0.0
# ZOZXOB                   1.0                         1.0    0.0  ...    0.0
# ZZZDWY01                 0.0                         0.0    0.0  ...    0.0
#
#           HydroPeroxide  Non Aromatic Carbonate  Non Aromatic Alkyne  \
# Refcode
# ABAWEG01            0.0                     0.0                  0.0
# ABEJIC              0.0                     0.0                  0.0
# ABEJOH              0.0                     0.0                  0.0
# ABEWAG              0.0                     0.0                  0.0
# ACETAC07            0.0                     0.0                  0.0
# ...                 ...                     ...                  ...
# YURRIN              0.0                     0.0                  0.0
# ZILFUV              0.0                     0.0                  0.0
# ZOJRAR01            0.0                     0.0                  0.0
# ZOZXOB              0.0                     0.0                  0.0
# ZZZDWY01            0.0                     0.0                  0.0
#
#           Isonitrile  Aromatic TertiaryAmine  Aldoxime  Non Aromatic Peroxide  \
# Refcode
# ABAWEG01         0.0                     0.0       0.0                    0.0
# ABEJIC           0.0                     0.0       0.0                    0.0
# ABEJOH           0.0                     0.0       0.0                    0.0
# ABEWAG           0.0                     0.0       0.0                    0.0
# ACETAC07         0.0                     0.0       0.0                    0.0
# ...              ...                     ...       ...                    ...
# YURRIN           0.0                     0.0       0.0                    0.0
# ZILFUV           0.0                     0.0       0.0                    0.0
# ZOJRAR01         0.0                     0.0       0.0                    0.0
# ZOZXOB           0.0                     0.0       0.0                    0.0
# ZZZDWY01         0.0                     0.0       0.0                    0.0
#
#           Carbonate  Acetal
# Refcode
# ABAWEG01        0.0     0.0
# ABEJIC          0.0     0.0
# ABEJOH          0.0     0.0
# ABEWAG          0.0     0.0
# ACETAC07        0.0     0.0
# ...             ...     ...
# YURRIN          0.0     0.0
# ZILFUV          0.0     0.0
# ZOJRAR01        0.0     0.0
# ZOZXOB          0.0     0.0
# ZZZDWY01        0.0     0.0
#
# [831 rows x 57 columns]

# %% [markdown]
# ## Python Table To Excel Export

# %% [markdown]
# Pandas Excel Exporter Interface with xlsxwriter
#
# <b>writer</b> is a <b>pandas</b> variable which interacts with dataframes (the tables defined here) for excel file I/O. The target excel file to interact with is your excel file configured in the script I/O files.

# %%
writer = pandas.ExcelWriter(MAIN_OUTPUT_PATH)

# %% [markdown]
# Excel Export with Pandas
#
# The code below places the two dataframes (tables) shown above into two seperate excel sheets in your `MAIN_OUTPUT_PATH` excel file. The columns are width adjusted to fit their assumed size, and then the writer object is closed.

# %%
##### All Functional Groups Data Sheet Export #####
df_all.to_excel(writer, sheet_name="all_data", freeze_panes=(1, 1))
all_sheet = writer.sheets["all_data"]
all_sheet.set_column(0, 0, 13)      # Refcode column width
all_sheet.set_column(1, 1, 125)     # SMILES column width
df_all_columns: list[str] = [str(col) for col in df_all.columns][1:]
for i, col in enumerate(df_all_columns):
    all_sheet.set_column(i+2, i+2, len(col)+7)

##### Exact Functional Groups Data Sheet Export #####
df_exact.to_excel(writer, sheet_name="exact_data", freeze_panes=(1, 1))
exact_sheet = writer.sheets["exact_data"]
exact_sheet.set_column(0, 0, 13)      # Refcode column width
exact_sheet.set_column(1, 1, 125)     # SMILES column width
df_exact_columns: list[str] = [str(col) for col in df_exact.columns][1:]
for i, col in enumerate(df_exact_columns):
    exact_sheet.set_column(i+2, i+2, len(col)+7)

##### Excel File Save #####
writer.close()

# %% [markdown]
# Please view your excel sheet at your `MAIN_OUTPUT_PATH` excel file to see the tabulated data placed into an excel file. If you encounter any significant errors, please first research as best you can to attempt to solve the problem. If the issue persist, then you may open an issue in the IFG GitHub repository.
